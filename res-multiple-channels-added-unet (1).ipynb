# %%
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Reshape, Permute, Activation, Input, \
    add, multiply
from keras.layers import concatenate, core, Dropout
from keras.models import Model
from keras.layers.merge import concatenate
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.layers.core import Lambda
#import keras.backend as K

#%tensorflow_version 1.x
import os
import keras
from keras.callbacks import TensorBoard
import tensorflow as tf
#import keras.backend.tensorflow_backend as K
import keras.backend as K
import matplotlib.pyplot as plt
from keras.callbacks import CSVLogger

# %%
import os
import numpy as np
from glob import glob
import tensorflow as tf
from sklearn.model_selection import train_test_split
import cv2

# %%
from __future__ import print_function
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
import numpy as np
import os
import skimage.io as io
import skimage.transform as trans
import cv2
import warnings

warnings.filterwarnings("ignore")

BackGround = [255, 255, 255]
road = [0, 0, 0]
# COLOR_DICT = np.array([BackGround, road])
one = [128, 128, 128]
two = [128, 0, 0]
three = [192, 192, 128]
four = [255, 69, 0]
five = [128, 64, 128]
six = [60, 40, 222]
seven = [128, 128, 0]
eight = [192, 128, 128]
nine = [64, 64, 128]
ten = [64, 0, 128]
eleven = [64, 64, 0]
twelve = [0, 128, 192]
COLOR_DICT = np.array([one, two,three,four,five,six,seven,eight,nine,ten,eleven,twelve])


class data_preprocess:
    def __init__(self, train_path=None, image_folder=None, label_folder=None,
                 valid_path=None,valid_image_folder =None,valid_label_folder = None,
                 test_path=None, save_path=None,
                 img_rows=256, img_cols=256,
                 flag_multi_class=False,
                 num_classes = 2):
        self.img_rows = img_rows
        self.img_cols = img_cols
        self.train_path = train_path
        self.image_folder = image_folder
        self.label_folder = label_folder
        self.valid_path = valid_path
        self.valid_image_folder = valid_image_folder
        self.valid_label_folder = valid_label_folder
        self.test_path = test_path
        self.save_path = save_path
        self.data_gen_args = dict(rotation_range=20,
                                  width_shift_range=0.002,
                                  shear_range=0.03,
                                  zoom_range=0.005,
                                  vertical_flip=True,
                                  horizontal_flip=True,
                                  fill_mode='nearest')
        self.image_color_mode = "rgb"
        self.label_color_mode = "grayscale"

        self.flag_multi_class = flag_multi_class
        self.num_class = num_classes
        self.target_size = (256, 256)
        self.img_type = 'png'

    def adjustData(self, img, label):
        if (self.flag_multi_class):
            img = img / 255.
            label = label[:, :, :, 0] if (len(label.shape) == 4) else label[:, :, 0]
            new_label = np.zeros(label.shape + (self.num_class,))
            for i in range(self.num_class):
                new_label[label == i, i] = 1
            label = new_label
        elif (np.max(img) > 1):
            #img = img / 255.
            #label = label / 255.
            #label[label >= 0.5] = 1
            #label[label < 0.5] = 0
            img2 =np.asarray(img)
            label2 =np.asarray(label)
            img2 =img2.astype('float32')
            label2 =label2.astype('float32')
            img2 /= 255.0
            label2 /= 255.0
            label2[label2 >= 0.5] = 1
            label2[label2 < 0.5] = 0
        return (img2, label2)

    def trainGenerator(self, batch_size, image_save_prefix="image", label_save_prefix="label",
                       save_to_dir=None, seed=7):
        '''
        can generate image and label at the same time
        use the same seed for image_datagen and label_datagen to ensure the transformation for image and label is the same
        if you want to visualize the results of generator, set save_to_dir = "your path"
        '''
        image_datagen = ImageDataGenerator(**self.data_gen_args)
        label_datagen = ImageDataGenerator(**self.data_gen_args)
        image_generator = image_datagen.flow_from_directory(
            self.train_path,
            classes=[self.image_folder],
            class_mode=None,
            color_mode=self.image_color_mode,
            target_size=self.target_size,
            batch_size=batch_size,
            save_to_dir=save_to_dir,
            save_prefix=image_save_prefix,
            seed=seed)
        label_generator = label_datagen.flow_from_directory(
            self.train_path,
            classes=[self.label_folder],
            class_mode=None,
            color_mode=self.label_color_mode,
            target_size=self.target_size,
            batch_size=batch_size,
            save_to_dir=save_to_dir,
            save_prefix=label_save_prefix,
            seed=seed)
        train_generator = zip(image_generator, label_generator)
        for (img, label) in train_generator:
            img, label = self.adjustData(img, label)
            yield (img, label)

    def testGenerator(self):
        filenames = os.listdir(self.test_path)
        for filename in filenames:
            img = io.imread(os.path.join(self.test_path, filename), as_gray=False)
            img = img[: , : , :3]
            img = img / 255.
            img = trans.resize(img, self.target_size, mode='constant')
            #img = np.reshape(img, img.shape + (1,)) if (not self.flag_multi_class) else img
            img = np.reshape(img, (1,) + img.shape)
            yield img

    def validLoad(self, batch_size,seed=7):
        image_datagen = ImageDataGenerator(rescale=0)
        label_datagen = ImageDataGenerator(rescale=0)
        image_generator = image_datagen.flow_from_directory(
            self.valid_path,
            classes=[self.valid_image_folder],
            class_mode=None,
            color_mode=self.image_color_mode,
            target_size=self.target_size,
            batch_size=batch_size,
            seed=seed)
        label_generator = label_datagen.flow_from_directory(
            self.valid_path,
            classes=[self.valid_label_folder],
            class_mode=None,
            color_mode=self.label_color_mode,
            target_size=self.target_size,
            batch_size=batch_size,
            seed=seed)
        train_generator = zip(image_generator, label_generator)
        for (img, label) in train_generator:
            img, label = self.adjustData(img, label)
            yield (img, label)
        # return imgs,labels
        
    def saveResult(self, npyfile, size, name,threshold=80):
        for i, item in enumerate(npyfile):
            img = item
            #print(img.shape)
            #break
            img_std = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
            if self.flag_multi_class:
                for row in range(len(img)):
                    for col in range(len(img[row])):
                        num = np.argmax(img[row][col])
                        img_std[row][col] = COLOR_DICT[num]
            else:
                for k in range(len(img)):
                    for j in range(len(img[k])):
                        num = img[k][j]
                        #print(num)
                        #break
                        if num < (threshold/255.0):
                            img_std[k][j] = road
                        else:
                            img_std[k][j] = BackGround
            #img_std = cv2.resize(img_std, size, interpolation=cv2.INTER_CUBIC)
            cv2.imwrite(os.path.join(self.save_path, ("%s_predict." + self.img_type) % (name)), img_std)

# %%
####  Metrics

from keras import backend as K
from keras.losses import binary_crossentropy
import tensorflow as tf
import numpy as np
def dice_coeff(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss
def iou_coeff(y_true, y_pred):
    smooth=1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union=K.sum(y_true_f) + K.sum(y_pred_f)-intersection
    mvalue=(intersection+smooth)/(union+smooth)
    return mvalue
def precision(y_true, y_pred):
    """Precision metric.

    Only computes a batch-wise average of precision.

    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall
def ACL5(y_true, y_pred): 

	#y_pred = K.cast(y_pred, dtype = 'float64')

	print(K.int_shape(y_pred))

	x = y_pred[:,1:,:,:] - y_pred[:,:-1,:,:] # horizontal and vertical directions 
	y = y_pred[:,:,1:,:] - y_pred[:,:,:-1,:]

	delta_x = x[:,1:,:-2,:]**2
	delta_y = y[:,:-2,1:,:]**2
	delta_u = K.abs(delta_x + delta_y) 

	epsilon = 0.00000001 # where is a parameter to avoid square root is zero in practice.
	w = 1####
	lenth = w * K.sum(K.sqrt(delta_u + epsilon)) # equ.(11) in the paper


	C_1 = np.ones((256, 256))
	C_2 = np.zeros((256, 256))

	region_in = K.abs(K.sum( y_pred[:,:,:,0] * ((y_true[:,:,:,0] - C_1)**2) ) ) # equ.(12) in the paper
	region_out = K.abs(K.sum( (1-y_pred[:,:,:,0]) * ((y_true[:,:,:,0] - C_2)**2) )) # equ.(12) in the paper

	lambdaP = 5 # lambda parameter could be various.
	
	loss =  lenth + lambdaP * ((region_in) + (region_out)) 

	return loss
def ACL5_mod(y_true, y_pred): 

	#y_pred = K.cast(y_pred, dtype = 'float64')

	print(K.int_shape(y_pred))

	x = y_pred[:,1:,:,:] - y_pred[:,:-1,:,:] # horizontal and vertical directions 
	y = y_pred[:,:,1:,:] - y_pred[:,:,:-1,:]

	delta_x = x[:,1:,:-2,:]**2
	delta_y = y[:,:-2,1:,:]**2
	delta_u = K.abs(delta_x + delta_y) 

	epsilon = 0.00000001 # where is a parameter to avoid square root is zero in practice.
	w = 1####
	lenth = w * K.sum(K.sqrt(delta_u + epsilon)) # equ.(11) in the paper


	C_1 = np.ones((256, 256))
	C_2 = np.zeros((256, 256))

	region_in = K.abs(K.sum( y_pred[:,:,:,0] * ((y_true[:,:,:,0] - C_1)**2) ) ) # equ.(12) in the paper
	region_out = K.abs(K.sum( (1-y_pred[:,:,:,0]) * ((y_true[:,:,:,0] - C_2)**2) )) # equ.(12) in the paper

	lambdaP = 5 # lambda parameter could be various.
	
	loss =  lenth + lambdaP * ((region_in) + (region_out*1.4)) 

	return loss

# %%
beta = 0.25
alpha = 0.25
gamma = 2
epsilon = 1e-5
smooth = 1

def tversky_index( y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1 - y_pred_pos))
    false_pos = K.sum((1 - y_true_pos) * y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth) / (true_pos + alpha * false_neg + (
                1 - alpha) * false_pos + smooth)

def tversky_loss( y_true, y_pred):
    return 1 - tversky_index(y_true, y_pred)

def focal_tversky( y_true, y_pred):
    pt_1 = tversky_index(y_true, y_pred)
    gamma = 0.75
    return K.pow((1 - pt_1), gamma)

def dsc(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - dsc(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

# %%
# %env SM_FRAMEWORK=tf.keras
# Out:
# env: SM_FRAMEWORK=tf.keras

# %%
# !pip install segmentation_models
import segmentation_models
from segmentation_models.losses import bce_jaccard_loss
# Out:
# Requirement already satisfied: segmentation_models in /opt/conda/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: image-classifiers==1.0.0 in /opt/conda/lib/python3.7/site-packages (from segmentation_models) (1.0.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /opt/conda/lib/python3.7/site-packages (from segmentation_models) (1.0.8)
# Requirement already satisfied: efficientnet==1.0.0 in /opt/conda/lib/python3.7/site-packages (from segmentation_models) (1.0.0)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from efficientnet==1.0.0->segmentation_models) (0.18.2)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.19.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.15.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2021.7.2)
# Requirement already satisfied: imageio>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.9.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.4.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (8.2.0)
# Requirement already satisfied: scipy>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.6.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.1.1)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation_models) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation_models) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation_models) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation_models) (2.4.7)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx>=2.0->scikit-image->efficientnet==1.0.0->segmentation_models) (5.0.9)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
def ACL5_bce_jaccard_loss(y_true, y_pred):
    loss = ACL5(y_true, y_pred) + bce_jaccard_loss(y_true, y_pred)
    return loss


def focal_tversky_bce_jaccard_loss(y_true, y_pred):
    loss = focal_tversky(y_true, y_pred) + 2*bce_jaccard_loss(y_true, y_pred)
    return loss

def ACL5_bce_jaccard_loss_focal_tversky(y_true, y_pred):
    loss = ACL5(y_true, y_pred) + bce_jaccard_loss(y_true, y_pred) + focal_tversky(y_true, y_pred)
    return loss

# %%
from keras.layers import Input, Conv2D, UpSampling2D, BatchNormalization, Activation, add,average,concatenate , Conv2DTranspose
from keras.layers.core import Lambda
from keras.optimizers import *
from keras.losses import binary_crossentropy
#import tensorflow as tf
#import keras.backend as K
#################################################################################3


def Conv_bn_relu_1(num_filters,
                 kernel_size,
                 batchnorm=True,
                 strides=(2, 2),
                 padding='same'):

    def layer(input_tensor):
        x = Conv2D(num_filters, kernel_size,
                   padding=padding, kernel_initializer='he_normal',
                   strides=strides)(input_tensor)
        if batchnorm:
            x = BatchNormalization()(x)
        x = Activation('relu')(x)
        return x
    return layer


def Conv_bn_relu(num_filters,
                 kernel_size,
                 batchnorm=True,
                 strides=(1, 1),
                 padding='same'):

    def layer(input_tensor):
        x = Conv2D(num_filters, kernel_size,
                   padding=padding, kernel_initializer='he_normal',
                   strides=strides)(input_tensor)
        if batchnorm:
            x = BatchNormalization()(x)
        x = Activation('relu')(x)
        return x
    return layer


def SEblock():
    def layer(input_tensor):

        return x
    return layer

def slice_layer(x, slice_num, channel_input):
    output_list = []
    single_channel = channel_input//slice_num
    for i in range(slice_num):
        out = x[:, :, :, i*single_channel:(i+1)*single_channel]
        output_list.append(out)
    return output_list


def res2net_block(num_filters, slice_num):
    def layer(input_tensor):
        short_cut = input_tensor
        x = Conv_bn_relu(num_filters=num_filters, kernel_size=(1, 1))(input_tensor)
        slice_list = slice_layer(x, slice_num, x.shape[-1])
        side = Conv_bn_relu(num_filters=num_filters//slice_num, kernel_size=(3, 3))(slice_list[1])
        z = concatenate([slice_list[0], side])   # for one and second stage
        for i in range(2, len(slice_list)):
            y = Conv_bn_relu(num_filters=num_filters//slice_num, kernel_size=(3, 3))(add([side, slice_list[i]]))
            side = y
            z = concatenate([z, y])
        
        z = Conv_bn_relu(num_filters=num_filters, kernel_size=(1, 1))(z)
        out = concatenate([z, short_cut])
        return out
    return layer

#512 512 3
#256 256 64

#128 128 128    ==> 64 in Conv_bn_relu_1 and res2net_block

#64 64 256     ==>  128 in Conv_bn_relu_1 and res2net_block


#x = Input((256, 256, 256))
#print(x.shape)
#x_conv_nor = Conv_bn_relu_1(256, (3, 3))(x) # Reducing the Size
#print(x_conv_nor.shape)
#out = slice_layer(x_conv_nor, 8, 512)
#print(out)
#print(len(out))
#x = res2net_block(256, 8)(x_conv_nor)    # Res2Net which 
#print(x.shape)


###################################################################################################################################

IMG_SIZE = 256
h_heuns_method=0.5


def res_block(x, nb_filters, strides):
    res_path = BatchNormalization()(x)
    res_path = Activation(activation='relu')(res_path)
    res_path = Conv2D(filters=nb_filters[0], kernel_size=(3, 3), padding='same' ,strides=strides[0])(res_path)
    

    res_path = BatchNormalization()(res_path)
    res_path = Activation(activation='relu')(res_path)
    res_path = Dropout(0.2)(res_path)
    res_path = Conv2D(filters=nb_filters[1], kernel_size=(3, 3), padding='same',strides=strides[1])(res_path)
    hpath = Lambda(lambda x: x * h_heuns_method)(res_path)

    shortcut = Conv2D(nb_filters[1], kernel_size=(1, 1),strides=strides[0])(x)
    shortcut = BatchNormalization()(shortcut)
    

    res_path = add([shortcut, hpath])#suma corta
    return res_path

def res_block2(x,y,nb_filters, strides):
    res_path = BatchNormalization()(x)
    res_path = Activation(activation='relu')(res_path)

    res_path = Conv2D(filters=nb_filters[0], kernel_size=(3, 3), padding='same' ,strides=strides[0])(res_path)
    res_path = BatchNormalization()(res_path)
    res_path = Activation(activation='relu')(res_path)
    res_path = Dropout(0.2)(res_path)
    
    res_path = Conv2D(filters=nb_filters[1], kernel_size=(3, 3), padding='same',strides=strides[1])(res_path)
    hpath = Lambda(lambda x: x * h_heuns_method)(res_path)

    shortcut = Conv2D(nb_filters[1], kernel_size=(1, 1),strides=strides[0])(x)
    shortcut = BatchNormalization()(shortcut)

    res_path = add([shortcut, hpath])#suma corta

    res_path = average([y, res_path])#suma doble 
    return res_path


def encoder1(x):
    to_decoder = []

    main_path = Conv2D(filters=64, kernel_size=(3, 3), padding='same', strides=(1, 1))(x)
    main_path = BatchNormalization()(main_path)
    main_path = Activation(activation='relu')(main_path)

    main_path = Conv2D(filters=64, kernel_size=(3, 3), padding='same', strides=(1, 1))(main_path)
    hpath = Lambda(lambda x: x * h_heuns_method)(main_path)

    shortcut = Conv2D(filters=64, kernel_size=(1, 1), strides=(1, 1))(x)
    shortcut = BatchNormalization()(shortcut)

    main_path = add([shortcut, hpath])#suma corta
    main_path  =  res2net_block(num_filters = 128 , slice_num = 4 )(main_path)          ####################### I added
    to_decoder.append(main_path)


    s1 = Conv2D(filters=128, kernel_size=(1, 1), strides=(2, 2))(x)
    s1 = BatchNormalization()(s1)

    main_path = res_block2(main_path,s1, [128, 128], [(2, 2), (1, 1)])
    main_path  =  res2net_block(num_filters = 128 , slice_num = 4 )(main_path)            ####################### I added

    to_decoder.append(main_path)

    main_path = res_block(main_path, [256, 256], [(2, 2), (1, 1)])
    main_path  =  res2net_block(num_filters = 256 , slice_num = 4 )(main_path)             ####################### I added
    to_decoder.append(main_path)

    s2 = Conv2D(filters=512, kernel_size=(1, 1), strides=(4, 4))(to_decoder[1])
    s2 = BatchNormalization()(s2)
    main_path = res_block2(main_path,s2, [512, 512], [(2, 2), (1, 1)])
    main_path  =  res2net_block(num_filters = 512 , slice_num = 4 )(main_path)               ####################### I added
    to_decoder.append(main_path)

    return to_decoder


def decoder1(x, from_encoder):
    
    ##main_path = UpSampling2D(size=(2, 2))(x)#32x32
    main_path = Conv2DTranspose(512, [2, 2], strides=[2, 2])(x)
    main_path = BatchNormalization()(main_path)
    main_path1 = concatenate([main_path, from_encoder[3]], axis=3)
    main_path = res_block(main_path1, [512, 512], [(1, 1), (1, 1)])
    main_path  =  res2net_block(num_filters = 512 , slice_num = 4 )(main_path)                 ####################### I added


    ##main_path = UpSampling2D(size=(2, 2))(main_path)###64x64
    # = Conv2DTranspose(out_channel, [2, 2], strides=[2, 2])(main_path)
    main_path = Conv2DTranspose(512, [2, 2], strides=[2, 2])(main_path)
    main_path = BatchNormalization()(main_path)
    main_path = concatenate([main_path, from_encoder[2]], axis=3)
    ##u1 = UpSampling2D(size=(2, 2))(main_path1)#
    u1 = Conv2DTranspose(256, [2, 2], strides=[2, 2])(main_path1)
    u1 = Conv2D(256, kernel_size=(1, 1),strides=(1, 1))(u1)
    u1 = BatchNormalization()(u1)
    main_path = res_block2(main_path,u1, [256, 256], [(1, 1), (1, 1)])#
    main_path  =  res2net_block(num_filters = 256 , slice_num = 4 )(main_path)                  ####################### I added


    #main_path = UpSampling2D(size=(2, 2))(main_path)#128x128
    main_path = Conv2DTranspose(128, [2, 2], strides=[2, 2])(main_path)
    main_path = BatchNormalization()(main_path)
    main_path2 = concatenate([main_path, from_encoder[1]], axis=3)#
    main_path = res_block(main_path2, [128, 128], [(1, 1), (1, 1)])#
    main_path  =  res2net_block(num_filters = 128 , slice_num = 4 )(main_path)                     ####################### I added


    #main_path = UpSampling2D(size=(2, 2))(main_path)#256x256
    main_path = Conv2DTranspose(64, [2, 2], strides=[2, 2])(main_path)
    main_path = BatchNormalization()(main_path)
    main_path = concatenate([main_path, from_encoder[0]], axis=3)#256x256
    #u2 = UpSampling2D(size=(2,2))(main_path2)#
    u2 = Conv2DTranspose(64, [2, 2], strides=[2, 2])(main_path2)
    u2 = Conv2D(64, kernel_size=(1, 1),strides=(1, 1))(u2)#
    u2 = BatchNormalization()(u2)
    main_path = res_block2(main_path,u2, [64, 64], [(1, 1), (1, 1)])#256x256
    main_path  =  res2net_block(num_filters = 64 , slice_num = 4 )(main_path)                         ####################### I added          
    
    return main_path


def res2unet1(lrate=8.00E-05,pretrained_weights=None):
    print(lrate)
    input_size=(IMG_SIZE, IMG_SIZE, 3)
    inputs = Input(shape=input_size)

    to_decoder = encoder(inputs)

    path = res_block(to_decoder[3], [1024, 1024], [(2, 2), (1, 1)])####bridge

    path = decoder(path, from_encoder=to_decoder)

    path = Conv2D(64, kernel_size=(3, 3),activation='relu', padding='same', strides=(1, 1))(path)     ####################### I added
    path = Conv2D(2, kernel_size=(3, 3),activation='relu', padding='same', strides=(1, 1))(path)
    path = Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(path)
    model = Model(inputs=inputs, outputs=path)
    model.compile(optimizer=Adam(lr=lrate), loss=ACL5, metrics=[bce_jaccard_loss , ACL5 ,  dice_loss ,iou_coeff ,precision ,recall])
    model.summary()
    if (pretrained_weights):
        model.load_weights(pretrained_weights)
    return model

# %%
from keras.layers import Input, Conv2D, UpSampling2D, BatchNormalization, Activation, add,average,concatenate , Conv2DTranspose
from keras.layers.core import Lambda
from keras.optimizers import *
from keras.losses import binary_crossentropy
#import tensorflow as tf
#import keras.backend as K
#################################################################################3


def Conv_bn_relu_1(num_filters,
                 kernel_size,
                 batchnorm=True,
                 strides=(2, 2),
                 padding='same'):

    def layer(input_tensor):
        x = Conv2D(num_filters, kernel_size,
                   padding=padding, kernel_initializer='he_normal',
                   strides=strides)(input_tensor)
        if batchnorm:
            x = BatchNormalization()(x)
        x = Activation('relu')(x)
        return x
    return layer


def Conv_bn_relu(num_filters,
                 kernel_size,
                 batchnorm=True,
                 strides=(1, 1),
                 padding='same'):

    def layer(input_tensor):
        x = Conv2D(num_filters, kernel_size,
                   padding=padding, kernel_initializer='he_normal',
                   strides=strides)(input_tensor)
        if batchnorm:
            x = BatchNormalization()(x)
        x = Activation('relu')(x)
        return x
    return layer


def SEblock():
    def layer(input_tensor):

        return x
    return layer

def slice_layer(x, slice_num, channel_input):
    output_list = []
    single_channel = channel_input//slice_num
    for i in range(slice_num):
        out = x[:, :, :, i*single_channel:(i+1)*single_channel]
        output_list.append(out)
    return output_list


def res2net_block(num_filters, slice_num):
    def layer(input_tensor):
        short_cut = input_tensor
        x = Conv_bn_relu(num_filters=num_filters, kernel_size=(1, 1))(input_tensor)
        slice_list = slice_layer(x, slice_num, x.shape[-1])
        side = Conv_bn_relu(num_filters=num_filters//slice_num, kernel_size=(3, 3))(slice_list[1])
        z = concatenate([slice_list[0], side])   # for one and second stage
        for i in range(2, len(slice_list)):
            y = Conv_bn_relu(num_filters=num_filters//slice_num, kernel_size=(3, 3))(add([side, slice_list[i]]))
            side = y
            z = concatenate([z, y])
        
        z = Conv_bn_relu(num_filters=num_filters, kernel_size=(1, 1))(z)
        out = concatenate([z, short_cut])
        return out
    return layer

#512 512 3
#256 256 64

#128 128 128    ==> 64 in Conv_bn_relu_1 and res2net_block

#64 64 256     ==>  128 in Conv_bn_relu_1 and res2net_block


#x = Input((256, 256, 256))
#print(x.shape)
#x_conv_nor = Conv_bn_relu_1(256, (3, 3))(x) # Reducing the Size
#print(x_conv_nor.shape)
#out = slice_layer(x_conv_nor, 8, 512)
#print(out)
#print(len(out))
#x = res2net_block(256, 8)(x_conv_nor)    # Res2Net which 
#print(x.shape)


###################################################################################################################################

IMG_SIZE = 256
h_heuns_method=0.5


def res_block(x, nb_filters, strides):
    res_path = BatchNormalization()(x)
    res_path = Activation(activation='relu')(res_path)
    res_path = Conv2D(filters=nb_filters[0], kernel_size=(3, 3), padding='same' ,strides=strides[0])(res_path)
    

    res_path = BatchNormalization()(res_path)
    res_path = Activation(activation='relu')(res_path)
    res_path = Dropout(0.2)(res_path)
    res_path = Conv2D(filters=nb_filters[1], kernel_size=(3, 3), padding='same',strides=strides[1])(res_path)
    hpath = Lambda(lambda x: x * h_heuns_method)(res_path)

    shortcut = Conv2D(nb_filters[1], kernel_size=(1, 1),strides=strides[0])(x)
    shortcut = BatchNormalization()(shortcut)
    

    res_path = add([shortcut, hpath])#suma corta
    return res_path

def res_block2(x,y,nb_filters, strides):
    res_path = BatchNormalization()(x)
    res_path = Activation(activation='relu')(res_path)

    res_path = Conv2D(filters=nb_filters[0], kernel_size=(3, 3), padding='same' ,strides=strides[0])(res_path)
    res_path = BatchNormalization()(res_path)
    res_path = Activation(activation='relu')(res_path)
    res_path = Dropout(0.2)(res_path)
    
    res_path = Conv2D(filters=nb_filters[1], kernel_size=(3, 3), padding='same',strides=strides[1])(res_path)
    hpath = Lambda(lambda x: x * h_heuns_method)(res_path)

    shortcut = Conv2D(nb_filters[1], kernel_size=(1, 1),strides=strides[0])(x)
    shortcut = BatchNormalization()(shortcut)

    res_path = add([shortcut, hpath])#suma corta

    res_path = average([y, res_path])#suma doble 
    return res_path


def encoder(x):
    to_decoder = []

    main_path = Conv2D(filters=64, kernel_size=(3, 3), padding='same', strides=(1, 1))(x)
    main_path = BatchNormalization()(main_path)
    main_path = Activation(activation='relu')(main_path)

    #main_path = Conv2D(filters=64, kernel_size=(3, 3), padding='same', strides=(1, 1))(main_path)
    #hpath = Lambda(lambda x: x * h_heuns_method)(main_path)

    #shortcut = Conv2D(filters=64, kernel_size=(1, 1), strides=(1, 1))(x)
    #shortcut = BatchNormalization()(shortcut)

    #main_path = add([shortcut, hpath])#suma corta
    main_path  =  res2net_block(num_filters = 64 , slice_num = 4 )(main_path)          ####################### I added
    to_decoder.append(main_path)


    s1 = Conv2D(filters=128, kernel_size=(1, 1), strides=(2, 2))(main_path)
    s1 = BatchNormalization()(s1)
    s1 = Activation(activation='relu')(s1)
    #main_path = res_block2(main_path,s1, [128, 128], [(2, 2), (1, 1)])
    main_path  =  res2net_block(num_filters = 128 , slice_num = 4 )(s1)            ####################### I added

    to_decoder.append(main_path)
    
    s2 = Conv2D(filters=256, kernel_size=(1, 1), strides=(2, 2))(main_path)
    s2 = BatchNormalization()(s2)
    s2 = Activation(activation='relu')(s2)
    #main_path = res_block(main_path, [256, 256], [(2, 2), (1, 1)])
    main_path  =  res2net_block(num_filters = 256 , slice_num = 4 )(s2)             ####################### I added
    to_decoder.append(main_path)

    s3 = Conv2D(filters=512, kernel_size=(1, 1), strides=(2, 2))(main_path)
    s3 = BatchNormalization()(s3)
    s3 = Activation(activation='relu')(s3)
    #main_path = res_block2(main_path,s2, [512, 512], [(2, 2), (1, 1)])
    main_path  =  res2net_block(num_filters = 512 , slice_num = 4 )(s3)               ####################### I added
    to_decoder.append(main_path)

    return to_decoder


def decoder(x, from_encoder):
    
    ##main_path = UpSampling2D(size=(2, 2))(x)#32x32
    #main_path  =  res2net_block(num_filters = 512 , slice_num = 4 )(x)
    main_path = Conv2DTranspose(512, [2, 2], strides=[2, 2])(x)
    main_path = BatchNormalization()(main_path)
    main_path = concatenate([main_path, from_encoder[3]], axis=3)
    #main_path = res_block(main_path1, [512, 512], [(1, 1), (1, 1)])
    main_path  =  res2net_block(num_filters = 512 , slice_num = 4 )(main_path)                 ####################### I added


    ##main_path = UpSampling2D(size=(2, 2))(main_path)###64x64
    # = Conv2DTranspose(out_channel, [2, 2], strides=[2, 2])(main_path)
    main_path = Conv2DTranspose(256, [2, 2], strides=[2, 2])(main_path)
    main_path = BatchNormalization()(main_path)
    main_path = concatenate([main_path, from_encoder[2]], axis=3)
    ##u1 = UpSampling2D(size=(2, 2))(main_path1)#
    #u1 = Conv2DTranspose(256, [2, 2], strides=[2, 2])(main_path1)
    #u1 = Conv2D(256, kernel_size=(1, 1),strides=(1, 1))(u1)
    #u1 = BatchNormalization()(u1)
    #main_path = res_block2(main_path,u1, [256, 256], [(1, 1), (1, 1)])#
    main_path  =  res2net_block(num_filters = 256 , slice_num = 4 )(main_path)                  ####################### I added


    #main_path = UpSampling2D(size=(2, 2))(main_path)#128x128
    main_path = Conv2DTranspose(128, [2, 2], strides=[2, 2])(main_path)
    main_path = BatchNormalization()(main_path)
    main_path = concatenate([main_path, from_encoder[1]], axis=3)#
    #main_path = res_block(main_path2, [128, 128], [(1, 1), (1, 1)])#
    main_path  =  res2net_block(num_filters = 128 , slice_num = 4 )(main_path)                     ####################### I added


    #main_path = UpSampling2D(size=(2, 2))(main_path)#256x256
    main_path = Conv2DTranspose(64, [2, 2], strides=[2, 2])(main_path)
    main_path = BatchNormalization()(main_path)
    main_path = concatenate([main_path, from_encoder[0]], axis=3)#256x256
    #u2 = UpSampling2D(size=(2,2))(main_path2)#
    #u2 = Conv2DTranspose(64, [2, 2], strides=[2, 2])(main_path2)
    #u2 = Conv2D(64, kernel_size=(1, 1),strides=(1, 1))(u2)#
    #u2 = BatchNormalization()(u2)
    #main_path = res_block2(main_path,u2, [64, 64], [(1, 1), (1, 1)])#256x256
    main_path  =  res2net_block(num_filters = 64 , slice_num = 4 )(main_path)                         ####################### I added          
    
    return main_path


def res2unet(lrate=8.00E-05,pretrained_weights=None):
    print(lrate)
    input_size=(IMG_SIZE, IMG_SIZE, 3)
    inputs = Input(shape=input_size)

    to_decoder = encoder(inputs)

    path = res_block(to_decoder[3], [1024, 1024], [(2, 2), (1, 1)])####bridge
    
    #main_path = BatchNormalization()(main_path)
    path = res2net_block(num_filters = 1024 , slice_num = 8 )(path)

    path = decoder(path, from_encoder=to_decoder)

    path = Conv2D(64, kernel_size=(3, 3),activation='relu', padding='same', strides=(1, 1))(path)     ####################### I added
    path = Conv2D(2, kernel_size=(3, 3),activation='relu', padding='same', strides=(1, 1))(path)
    path = Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(path)
    model = Model(inputs=inputs, outputs=path)
    model.compile(optimizer=Adam(lr=lrate), loss=ACL5, metrics=[ACL5 , bce_jaccard_loss, dice_loss,iou_coeff,precision,recall])
    model.summary()
    if (pretrained_weights):
        model.load_weights(pretrained_weights)
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau


#path to images
train_path = "../input/training/training"
image_folder = "images"
label_folder = "label"
valid_path =  "../input/validation/Validation"
valid_image_folder ="images"
valid_label_folder = "label"
log_filepath = './log'
flag_multi_class = False
num_classes = 2
test_path = "../input/testdata/Test/images"
save_path = "./"
dp = data_preprocess(train_path=train_path,image_folder=image_folder,label_folder=label_folder,
                     valid_path=valid_path,valid_image_folder=valid_image_folder,valid_label_folder=valid_label_folder,
                     flag_multi_class=flag_multi_class,
                     num_classes=num_classes , test_path = test_path , save_path = save_path)

train_data = dp.trainGenerator(batch_size=2)
valid_data = dp.validLoad(batch_size=1)
test_data = dp.testGenerator()

model = res2unet(lrate=7.00E-05 )# , pretrained_weights = "../input/weights-res2net-conv2dtranspose/Res2Net_Conv2DTranspose.hdf5")
learning_rate_reduction = ReduceLROnPlateau(
    monitor = 'val_iou_coeff', 
    patience = 2, 
    verbose = 1, 
    factor = 0.2, 
    min_lr = 0.0000001
    )

model_checkpoint1 = keras.callbacks.ModelCheckpoint('Res2Net.hdf5', monitor='val_dice_loss',verbose=1,mode='min',save_best_only=True)
csv_logger = CSVLogger('trainingRes2Net.log', append=True, separator=';')
history = model.fit_generator(train_data,
                              steps_per_epoch=1912,epochs=20,
                              validation_steps=207,
                              validation_data=valid_data,
                              callbacks=[model_checkpoint1,csv_logger  ])
# Out:
# 7e-05
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 256, 256, 64) 1792        input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 256, 256, 64) 256         conv2d_240[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 256, 256, 64) 0           batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 256, 256, 64) 4160        activation_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 256, 256, 64) 256         conv2d_241[0][0]
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 256, 256, 64) 0           batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_161 (S (None, 256, 256, 16) 0           activation_221[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 256, 256, 16) 2320        tf.__operators__.getitem_161[0][0
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 256, 256, 16) 64          conv2d_242[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 256, 256, 16) 0           batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_162 (S (None, 256, 256, 16) 0           activation_221[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, 256, 256, 16) 0           activation_222[0][0]
#                                                                  tf.__operators__.getitem_162[0][0
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 256, 256, 16) 2320        add_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 256, 256, 16) 64          conv2d_243[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 256, 256, 16) 0           batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_163 (S (None, 256, 256, 16) 0           activation_221[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, 256, 256, 16) 0           activation_223[0][0]
#                                                                  tf.__operators__.getitem_163[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_160 (S (None, 256, 256, 16) 0           activation_221[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 256, 256, 16) 2320        add_95[0][0]
# __________________________________________________________________________________________________
# concatenate_176 (Concatenate)   (None, 256, 256, 32) 0           tf.__operators__.getitem_160[0][0
#                                                                  activation_222[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 256, 256, 16) 64          conv2d_244[0][0]
# __________________________________________________________________________________________________
# concatenate_177 (Concatenate)   (None, 256, 256, 48) 0           concatenate_176[0][0]
#                                                                  activation_223[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 256, 256, 16) 0           batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# concatenate_178 (Concatenate)   (None, 256, 256, 64) 0           concatenate_177[0][0]
#                                                                  activation_224[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 256, 256, 64) 4160        concatenate_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 256, 256, 64) 256         conv2d_245[0][0]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 256, 256, 64) 0           batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# concatenate_179 (Concatenate)   (None, 256, 256, 128 0           activation_225[0][0]
#                                                                  activation_220[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 128, 128, 128 16512       concatenate_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 128, 128, 128 512         conv2d_246[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 128, 128, 128 0           batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 128, 128, 128 16512       activation_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 128, 128, 128 512         conv2d_247[0][0]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 128, 128, 128 0           batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_165 (S (None, 128, 128, 32) 0           activation_227[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 128, 128, 32) 9248        tf.__operators__.getitem_165[0][0
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 128, 128, 32) 128         conv2d_248[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 128, 128, 32) 0           batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_166 (S (None, 128, 128, 32) 0           activation_227[0][0]
# __________________________________________________________________________________________________
# add_96 (Add)                    (None, 128, 128, 32) 0           activation_228[0][0]
#                                                                  tf.__operators__.getitem_166[0][0
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 128, 128, 32) 9248        add_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 128, 128, 32) 128         conv2d_249[0][0]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 128, 128, 32) 0           batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_167 (S (None, 128, 128, 32) 0           activation_227[0][0]
# __________________________________________________________________________________________________
# add_97 (Add)                    (None, 128, 128, 32) 0           activation_229[0][0]
#                                                                  tf.__operators__.getitem_167[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_164 (S (None, 128, 128, 32) 0           activation_227[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 128, 128, 32) 9248        add_97[0][0]
# __________________________________________________________________________________________________
# concatenate_180 (Concatenate)   (None, 128, 128, 64) 0           tf.__operators__.getitem_164[0][0
#                                                                  activation_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 128, 128, 32) 128         conv2d_250[0][0]
# __________________________________________________________________________________________________
# concatenate_181 (Concatenate)   (None, 128, 128, 96) 0           concatenate_180[0][0]
#                                                                  activation_229[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 128, 128, 32) 0           batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# concatenate_182 (Concatenate)   (None, 128, 128, 128 0           concatenate_181[0][0]
#                                                                  activation_230[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 128, 128, 128 16512       concatenate_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 128, 128, 128 512         conv2d_251[0][0]
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, 128, 128, 128 0           batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# concatenate_183 (Concatenate)   (None, 128, 128, 256 0           activation_231[0][0]
#                                                                  activation_226[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 64, 64, 256)  65792       concatenate_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 64, 64, 256)  1024        conv2d_252[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, 64, 64, 256)  0           batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 64, 64, 256)  65792       activation_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 64, 64, 256)  1024        conv2d_253[0][0]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, 64, 64, 256)  0           batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_169 (S (None, 64, 64, 64)   0           activation_233[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 64, 64, 64)   36928       tf.__operators__.getitem_169[0][0
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 64, 64, 64)   256         conv2d_254[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 64, 64, 64)   0           batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_170 (S (None, 64, 64, 64)   0           activation_233[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, 64, 64, 64)   0           activation_234[0][0]
#                                                                  tf.__operators__.getitem_170[0][0
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 64, 64, 64)   36928       add_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 64, 64, 64)   256         conv2d_255[0][0]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 64, 64, 64)   0           batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_171 (S (None, 64, 64, 64)   0           activation_233[0][0]
# __________________________________________________________________________________________________
# add_99 (Add)                    (None, 64, 64, 64)   0           activation_235[0][0]
#                                                                  tf.__operators__.getitem_171[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_168 (S (None, 64, 64, 64)   0           activation_233[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 64, 64, 64)   36928       add_99[0][0]
# __________________________________________________________________________________________________
# concatenate_184 (Concatenate)   (None, 64, 64, 128)  0           tf.__operators__.getitem_168[0][0
#                                                                  activation_234[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 64, 64, 64)   256         conv2d_256[0][0]
# __________________________________________________________________________________________________
# concatenate_185 (Concatenate)   (None, 64, 64, 192)  0           concatenate_184[0][0]
#                                                                  activation_235[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 64, 64, 64)   0           batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# concatenate_186 (Concatenate)   (None, 64, 64, 256)  0           concatenate_185[0][0]
#                                                                  activation_236[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 64, 64, 256)  65792       concatenate_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 64, 64, 256)  1024        conv2d_257[0][0]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, 64, 64, 256)  0           batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# concatenate_187 (Concatenate)   (None, 64, 64, 512)  0           activation_237[0][0]
#                                                                  activation_232[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 32, 32, 512)  2048        conv2d_258[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 32, 32, 512)  0           batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 32, 32, 512)  262656      activation_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 32, 32, 512)  2048        conv2d_259[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, 32, 32, 512)  0           batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_173 (S (None, 32, 32, 128)  0           activation_239[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 32, 32, 128)  147584      tf.__operators__.getitem_173[0][0
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 32, 32, 128)  512         conv2d_260[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 32, 32, 128)  0           batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_174 (S (None, 32, 32, 128)  0           activation_239[0][0]
# __________________________________________________________________________________________________
# add_100 (Add)                   (None, 32, 32, 128)  0           activation_240[0][0]
#                                                                  tf.__operators__.getitem_174[0][0
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 32, 32, 128)  147584      add_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 32, 32, 128)  512         conv2d_261[0][0]
# __________________________________________________________________________________________________
# activation_241 (Activation)     (None, 32, 32, 128)  0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_175 (S (None, 32, 32, 128)  0           activation_239[0][0]
# __________________________________________________________________________________________________
# add_101 (Add)                   (None, 32, 32, 128)  0           activation_241[0][0]
#                                                                  tf.__operators__.getitem_175[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_172 (S (None, 32, 32, 128)  0           activation_239[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 32, 32, 128)  147584      add_101[0][0]
# __________________________________________________________________________________________________
# concatenate_188 (Concatenate)   (None, 32, 32, 256)  0           tf.__operators__.getitem_172[0][0
#                                                                  activation_240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 32, 32, 128)  512         conv2d_262[0][0]
# __________________________________________________________________________________________________
# concatenate_189 (Concatenate)   (None, 32, 32, 384)  0           concatenate_188[0][0]
#                                                                  activation_241[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 32, 32, 128)  0           batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# concatenate_190 (Concatenate)   (None, 32, 32, 512)  0           concatenate_189[0][0]
#                                                                  activation_242[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 32, 32, 512)  2048        conv2d_263[0][0]
# __________________________________________________________________________________________________
# activation_243 (Activation)     (None, 32, 32, 512)  0           batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# concatenate_191 (Concatenate)   (None, 32, 32, 1024) 0           activation_243[0][0]
#                                                                  activation_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 32, 32, 1024) 4096        concatenate_191[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 32, 32, 1024) 0           batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 16, 16, 1024) 9438208     activation_244[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 16, 16, 1024) 4096        conv2d_264[0][0]
# __________________________________________________________________________________________________
# activation_245 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 1024) 0           activation_245[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 16, 16, 1024) 1049600     concatenate_191[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 16, 16, 1024) 9438208     dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 16, 16, 1024) 4096        conv2d_266[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 16, 16, 1024) 0           conv2d_265[0][0]
# __________________________________________________________________________________________________
# add_102 (Add)                   (None, 16, 16, 1024) 0           batch_normalization_268[0][0]
#                                                                  lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 16, 16, 1024) 1049600     add_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 16, 16, 1024) 4096        conv2d_267[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_177 (S (None, 16, 16, 128)  0           activation_246[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 16, 16, 128)  147584      tf.__operators__.getitem_177[0][0
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 16, 16, 128)  512         conv2d_268[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, 16, 16, 128)  0           batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_178 (S (None, 16, 16, 128)  0           activation_246[0][0]
# __________________________________________________________________________________________________
# add_103 (Add)                   (None, 16, 16, 128)  0           activation_247[0][0]
#                                                                  tf.__operators__.getitem_178[0][0
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 16, 16, 128)  147584      add_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 16, 16, 128)  512         conv2d_269[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 16, 16, 128)  0           batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_179 (S (None, 16, 16, 128)  0           activation_246[0][0]
# __________________________________________________________________________________________________
# add_104 (Add)                   (None, 16, 16, 128)  0           activation_248[0][0]
#                                                                  tf.__operators__.getitem_179[0][0
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 16, 16, 128)  147584      add_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 16, 16, 128)  512         conv2d_270[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 16, 16, 128)  0           batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_180 (S (None, 16, 16, 128)  0           activation_246[0][0]
# __________________________________________________________________________________________________
# add_105 (Add)                   (None, 16, 16, 128)  0           activation_249[0][0]
#                                                                  tf.__operators__.getitem_180[0][0
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 16, 16, 128)  147584      add_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 16, 16, 128)  512         conv2d_271[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, 16, 16, 128)  0           batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_181 (S (None, 16, 16, 128)  0           activation_246[0][0]
# __________________________________________________________________________________________________
# add_106 (Add)                   (None, 16, 16, 128)  0           activation_250[0][0]
#                                                                  tf.__operators__.getitem_181[0][0
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 16, 16, 128)  147584      add_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 16, 16, 128)  512         conv2d_272[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, 16, 16, 128)  0           batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_182 (S (None, 16, 16, 128)  0           activation_246[0][0]
# __________________________________________________________________________________________________
# add_107 (Add)                   (None, 16, 16, 128)  0           activation_251[0][0]
#                                                                  tf.__operators__.getitem_182[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_176 (S (None, 16, 16, 128)  0           activation_246[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 16, 16, 128)  147584      add_107[0][0]
# __________________________________________________________________________________________________
# concatenate_192 (Concatenate)   (None, 16, 16, 256)  0           tf.__operators__.getitem_176[0][0
#                                                                  activation_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 16, 16, 128)  512         conv2d_273[0][0]
# __________________________________________________________________________________________________
# concatenate_193 (Concatenate)   (None, 16, 16, 384)  0           concatenate_192[0][0]
#                                                                  activation_248[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 16, 16, 128)  0           batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_183 (S (None, 16, 16, 128)  0           activation_246[0][0]
# __________________________________________________________________________________________________
# concatenate_194 (Concatenate)   (None, 16, 16, 512)  0           concatenate_193[0][0]
#                                                                  activation_249[0][0]
# __________________________________________________________________________________________________
# add_108 (Add)                   (None, 16, 16, 128)  0           activation_252[0][0]
#                                                                  tf.__operators__.getitem_183[0][0
# __________________________________________________________________________________________________
# concatenate_195 (Concatenate)   (None, 16, 16, 640)  0           concatenate_194[0][0]
#                                                                  activation_250[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 16, 16, 128)  147584      add_108[0][0]
# __________________________________________________________________________________________________
# concatenate_196 (Concatenate)   (None, 16, 16, 768)  0           concatenate_195[0][0]
#                                                                  activation_251[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 16, 16, 128)  512         conv2d_274[0][0]
# __________________________________________________________________________________________________
# concatenate_197 (Concatenate)   (None, 16, 16, 896)  0           concatenate_196[0][0]
#                                                                  activation_252[0][0]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, 16, 16, 128)  0           batch_normalization_276[0][0]
# __________________________________________________________________________________________________
# concatenate_198 (Concatenate)   (None, 16, 16, 1024) 0           concatenate_197[0][0]
#                                                                  activation_253[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 16, 16, 1024) 1049600     concatenate_198[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 16, 16, 1024) 4096        conv2d_275[0][0]
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# concatenate_199 (Concatenate)   (None, 16, 16, 2048) 0           activation_254[0][0]
#                                                                  add_102[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 32, 32, 512)  4194816     concatenate_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 32, 32, 512)  2048        conv2d_transpose_16[0][0]
# __________________________________________________________________________________________________
# concatenate_200 (Concatenate)   (None, 32, 32, 1536) 0           batch_normalization_278[0][0]
#                                                                  concatenate_191[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 32, 32, 512)  786944      concatenate_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 32, 32, 512)  2048        conv2d_276[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 32, 32, 512)  0           batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_185 (S (None, 32, 32, 128)  0           activation_255[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 32, 32, 128)  147584      tf.__operators__.getitem_185[0][0
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 32, 32, 128)  512         conv2d_277[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 32, 32, 128)  0           batch_normalization_280[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_186 (S (None, 32, 32, 128)  0           activation_255[0][0]
# __________________________________________________________________________________________________
# add_109 (Add)                   (None, 32, 32, 128)  0           activation_256[0][0]
#                                                                  tf.__operators__.getitem_186[0][0
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 32, 32, 128)  147584      add_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281 (BatchN (None, 32, 32, 128)  512         conv2d_278[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 32, 32, 128)  0           batch_normalization_281[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_187 (S (None, 32, 32, 128)  0           activation_255[0][0]
# __________________________________________________________________________________________________
# add_110 (Add)                   (None, 32, 32, 128)  0           activation_257[0][0]
#                                                                  tf.__operators__.getitem_187[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_184 (S (None, 32, 32, 128)  0           activation_255[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 32, 32, 128)  147584      add_110[0][0]
# __________________________________________________________________________________________________
# concatenate_201 (Concatenate)   (None, 32, 32, 256)  0           tf.__operators__.getitem_184[0][0
#                                                                  activation_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_282 (BatchN (None, 32, 32, 128)  512         conv2d_279[0][0]
# __________________________________________________________________________________________________
# concatenate_202 (Concatenate)   (None, 32, 32, 384)  0           concatenate_201[0][0]
#                                                                  activation_257[0][0]
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 32, 32, 128)  0           batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# concatenate_203 (Concatenate)   (None, 32, 32, 512)  0           concatenate_202[0][0]
#                                                                  activation_258[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_283 (BatchN (None, 32, 32, 512)  2048        conv2d_280[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 32, 32, 512)  0           batch_normalization_283[0][0]
# __________________________________________________________________________________________________
# concatenate_204 (Concatenate)   (None, 32, 32, 2048) 0           activation_259[0][0]
#                                                                  concatenate_200[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 64, 64, 256)  2097408     concatenate_204[0][0]
# __________________________________________________________________________________________________
# batch_normalization_284 (BatchN (None, 64, 64, 256)  1024        conv2d_transpose_17[0][0]
# __________________________________________________________________________________________________
# concatenate_205 (Concatenate)   (None, 64, 64, 768)  0           batch_normalization_284[0][0]
#                                                                  concatenate_187[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 64, 64, 256)  196864      concatenate_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_285 (BatchN (None, 64, 64, 256)  1024        conv2d_281[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 64, 64, 256)  0           batch_normalization_285[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_189 (S (None, 64, 64, 64)   0           activation_260[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 64, 64, 64)   36928       tf.__operators__.getitem_189[0][0
# __________________________________________________________________________________________________
# batch_normalization_286 (BatchN (None, 64, 64, 64)   256         conv2d_282[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, 64, 64, 64)   0           batch_normalization_286[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_190 (S (None, 64, 64, 64)   0           activation_260[0][0]
# __________________________________________________________________________________________________
# add_111 (Add)                   (None, 64, 64, 64)   0           activation_261[0][0]
#                                                                  tf.__operators__.getitem_190[0][0
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 64, 64, 64)   36928       add_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_287 (BatchN (None, 64, 64, 64)   256         conv2d_283[0][0]
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 64, 64, 64)   0           batch_normalization_287[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_191 (S (None, 64, 64, 64)   0           activation_260[0][0]
# ...
# conv2d_290 (Conv2D)             (None, 128, 128, 128 16512       concatenate_213[0][0]
# __________________________________________________________________________________________________
# batch_normalization_295 (BatchN (None, 128, 128, 128 512         conv2d_290[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 128, 128, 128 0           batch_normalization_295[0][0]
# __________________________________________________________________________________________________
# concatenate_214 (Concatenate)   (None, 128, 128, 512 0           activation_269[0][0]
#                                                                  concatenate_210[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 256, 256, 64) 131136      concatenate_214[0][0]
# __________________________________________________________________________________________________
# batch_normalization_296 (BatchN (None, 256, 256, 64) 256         conv2d_transpose_19[0][0]
# __________________________________________________________________________________________________
# concatenate_215 (Concatenate)   (None, 256, 256, 192 0           batch_normalization_296[0][0]
#                                                                  concatenate_179[0][0]
# __________________________________________________________________________________________________
# conv2d_291 (Conv2D)             (None, 256, 256, 64) 12352       concatenate_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_297 (BatchN (None, 256, 256, 64) 256         conv2d_291[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 256, 256, 64) 0           batch_normalization_297[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_197 (S (None, 256, 256, 16) 0           activation_270[0][0]
# __________________________________________________________________________________________________
# conv2d_292 (Conv2D)             (None, 256, 256, 16) 2320        tf.__operators__.getitem_197[0][0
# __________________________________________________________________________________________________
# batch_normalization_298 (BatchN (None, 256, 256, 16) 64          conv2d_292[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 256, 256, 16) 0           batch_normalization_298[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_198 (S (None, 256, 256, 16) 0           activation_270[0][0]
# __________________________________________________________________________________________________
# add_115 (Add)                   (None, 256, 256, 16) 0           activation_271[0][0]
#                                                                  tf.__operators__.getitem_198[0][0
# __________________________________________________________________________________________________
# conv2d_293 (Conv2D)             (None, 256, 256, 16) 2320        add_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_299 (BatchN (None, 256, 256, 16) 64          conv2d_293[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 256, 256, 16) 0           batch_normalization_299[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_199 (S (None, 256, 256, 16) 0           activation_270[0][0]
# __________________________________________________________________________________________________
# add_116 (Add)                   (None, 256, 256, 16) 0           activation_272[0][0]
#                                                                  tf.__operators__.getitem_199[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_196 (S (None, 256, 256, 16) 0           activation_270[0][0]
# __________________________________________________________________________________________________
# conv2d_294 (Conv2D)             (None, 256, 256, 16) 2320        add_116[0][0]
# __________________________________________________________________________________________________
# concatenate_216 (Concatenate)   (None, 256, 256, 32) 0           tf.__operators__.getitem_196[0][0
#                                                                  activation_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_300 (BatchN (None, 256, 256, 16) 64          conv2d_294[0][0]
# __________________________________________________________________________________________________
# concatenate_217 (Concatenate)   (None, 256, 256, 48) 0           concatenate_216[0][0]
#                                                                  activation_272[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 256, 256, 16) 0           batch_normalization_300[0][0]
# __________________________________________________________________________________________________
# concatenate_218 (Concatenate)   (None, 256, 256, 64) 0           concatenate_217[0][0]
#                                                                  activation_273[0][0]
# __________________________________________________________________________________________________
# conv2d_295 (Conv2D)             (None, 256, 256, 64) 4160        concatenate_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_301 (BatchN (None, 256, 256, 64) 256         conv2d_295[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 256, 256, 64) 0           batch_normalization_301[0][0]
# __________________________________________________________________________________________________
# concatenate_219 (Concatenate)   (None, 256, 256, 256 0           activation_274[0][0]
#                                                                  concatenate_215[0][0]
# __________________________________________________________________________________________________
# conv2d_296 (Conv2D)             (None, 256, 256, 64) 147520      concatenate_219[0][0]
# __________________________________________________________________________________________________
# conv2d_297 (Conv2D)             (None, 256, 256, 2)  1154        conv2d_296[0][0]
# __________________________________________________________________________________________________
# conv2d_298 (Conv2D)             (None, 256, 256, 1)  3           conv2d_297[0][0]
# ==================================================================================================
# Total params: 33,823,653
# Trainable params: 33,797,221
# Non-trainable params: 26,432
# __________________________________________________________________________________________________
# Found 600 images belonging to 1 classes.
# Found 600 images belonging to 1 classes.
# Epoch 1/20
# (None, 256, 256, 1)
# (None, 256, 256, 1)
# 1912/1912 [==============================] - ETA: 0s - loss: 0.6271 - ACL5: 23240.7825 - binary_crossentropy_plus_jaccard_loss: 0.6271 - dice_loss: 0.4278 - iou_coeff: 0.4395 - precision: 0.6092 - recall: 0.5838Found 200 images belonging to 1 classes.
# Found 200 images belonging to 1 classes.
# (None, 256, 256, 1)
# 1912/1912 [==============================] - 276s 140ms/step - loss: 0.6270 - ACL5: 23233.2180 - binary_crossentropy_plus_jaccard_loss: 0.6270 - dice_loss: 0.4277 - iou_coeff: 0.4396 - precision: 0.6092 - recall: 0.5838 - val_loss: 0.5376 - val_ACL5: 2878.2000 - val_binary_crossentropy_plus_jaccard_loss: 0.5376 - val_dice_loss: 0.3688 - val_iou_coeff: 0.5131 - val_precision: 0.6674 - val_recall: 0.6505
#
# Epoch 00001: val_dice_loss improved from inf to 0.36879, saving model to Res2Net.hdf5
# Epoch 2/20
# 1912/1912 [==============================] - 266s 139ms/step - loss: 0.4177 - ACL5: 4727.9431 - binary_crossentropy_plus_jaccard_loss: 0.4177 - dice_loss: 0.2495 - iou_coeff: 0.6136 - precision: 0.7619 - recall: 0.7758 - val_loss: 0.6691 - val_ACL5: 3085.0400 - val_binary_crossentropy_plus_jaccard_loss: 0.6691 - val_dice_loss: 0.4921 - val_iou_coeff: 0.3961 - val_precision: 0.6860 - val_recall: 0.4315
#
# Epoch 00002: val_dice_loss did not improve from 0.36879
# Epoch 3/20
# 1912/1912 [==============================] - 266s 139ms/step - loss: 0.4047 - ACL5: 4505.0686 - binary_crossentropy_plus_jaccard_loss: 0.4047 - dice_loss: 0.2425 - iou_coeff: 0.6259 - precision: 0.7715 - recall: 0.7769 - val_loss: 0.7387 - val_ACL5: 3836.7925 - val_binary_crossentropy_plus_jaccard_loss: 0.7387 - val_dice_loss: 0.5758 - val_iou_coeff: 0.3265 - val_precision: 0.5571 - val_recall: 0.3891
#
# Epoch 00003: val_dice_loss did not improve from 0.36879
# Epoch 4/20
# 1912/1912 [==============================] - 266s 139ms/step - loss: 0.3863 - ACL5: 4260.5400 - binary_crossentropy_plus_jaccard_loss: 0.3863 - dice_loss: 0.2266 - iou_coeff: 0.6424 - precision: 0.7870 - recall: 0.7915 - val_loss: 0.5073 - val_ACL5: 2335.2554 - val_binary_crossentropy_plus_jaccard_loss: 0.5073 - val_dice_loss: 0.3412 - val_iou_coeff: 0.5508 - val_precision: 0.7646 - val_recall: 0.5960
#
# Epoch 00004: val_dice_loss improved from 0.36879 to 0.34119, saving model to Res2Net.hdf5
# Epoch 5/20
# 1912/1912 [==============================] - 268s 140ms/step - loss: 0.3721 - ACL5: 4099.7966 - binary_crossentropy_plus_jaccard_loss: 0.3721 - dice_loss: 0.2182 - iou_coeff: 0.6555 - precision: 0.7939 - recall: 0.7978 - val_loss: 0.4981 - val_ACL5: 2756.4443 - val_binary_crossentropy_plus_jaccard_loss: 0.4981 - val_dice_loss: 0.3428 - val_iou_coeff: 0.5404 - val_precision: 0.6572 - val_recall: 0.7170
#
# Epoch 00005: val_dice_loss did not improve from 0.34119
# Epoch 6/20
# 1912/1912 [==============================] - 267s 140ms/step - loss: 0.3566 - ACL5: 3930.4982 - binary_crossentropy_plus_jaccard_loss: 0.3566 - dice_loss: 0.2061 - iou_coeff: 0.6700 - precision: 0.8056 - recall: 0.8098 - val_loss: 0.5460 - val_ACL5: 2523.5005 - val_binary_crossentropy_plus_jaccard_loss: 0.5460 - val_dice_loss: 0.3868 - val_iou_coeff: 0.5090 - val_precision: 0.7376 - val_recall: 0.5591
#
# Epoch 00006: val_dice_loss did not improve from 0.34119
# Epoch 7/20
# 1912/1912 [==============================] - 268s 140ms/step - loss: 0.3445 - ACL5: 3810.3343 - binary_crossentropy_plus_jaccard_loss: 0.3445 - dice_loss: 0.1971 - iou_coeff: 0.6808 - precision: 0.8106 - recall: 0.8185 - val_loss: 0.4329 - val_ACL5: 2141.5500 - val_binary_crossentropy_plus_jaccard_loss: 0.4329 - val_dice_loss: 0.2729 - val_iou_coeff: 0.6155 - val_precision: 0.7356 - val_recall: 0.7241
#
# Epoch 00007: val_dice_loss improved from 0.34119 to 0.27286, saving model to Res2Net.hdf5
# Epoch 8/20
#  191/1912 [=>............................] - ETA: 3:56 - loss: 0.3221 - ACL5: 3527.2367 - binary_crossentropy_plus_jaccard_loss: 0.3221 - dice_loss: 0.1837 - iou_coeff: 0.7005 - precision: 0.8211 - recall: 0.8322
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-3a430588b56b> in <module>
#      38                               validation_steps=207,
#      39                               validation_data=valid_data,
# ---> 40                               callbacks=[model_checkpoint1,csv_logger  ])
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1859         use_multiprocessing=use_multiprocessing,
#    1860         shuffle=shuffle,
# -> 1861         initial_epoch=initial_epoch)
#    1862
#    1863   def evaluate_generator(self,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model = res2unet(lrate=7.00E-05 , pretrained_weights = './Res2Net.hdf5')


history = model.fit_generator(train_data,
                              steps_per_epoch=1912,epochs=25,
                              validation_steps=207,
                              validation_data=valid_data,
                              callbacks=[model_checkpoint1,csv_logger , learning_rate_reduction])
# Out:
# 7e-05
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_476 (Conv2D)             (None, 256, 256, 64) 1792        input_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_482 (BatchN (None, 256, 256, 64) 256         conv2d_476[0][0]
# __________________________________________________________________________________________________
# activation_440 (Activation)     (None, 256, 256, 64) 0           batch_normalization_482[0][0]
# __________________________________________________________________________________________________
# conv2d_477 (Conv2D)             (None, 256, 256, 64) 4160        activation_440[0][0]
# __________________________________________________________________________________________________
# batch_normalization_483 (BatchN (None, 256, 256, 64) 256         conv2d_477[0][0]
# __________________________________________________________________________________________________
# activation_441 (Activation)     (None, 256, 256, 64) 0           batch_normalization_483[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_321 (S (None, 256, 256, 16) 0           activation_441[0][0]
# __________________________________________________________________________________________________
# conv2d_478 (Conv2D)             (None, 256, 256, 16) 2320        tf.__operators__.getitem_321[0][0
# __________________________________________________________________________________________________
# batch_normalization_484 (BatchN (None, 256, 256, 16) 64          conv2d_478[0][0]
# __________________________________________________________________________________________________
# activation_442 (Activation)     (None, 256, 256, 16) 0           batch_normalization_484[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_322 (S (None, 256, 256, 16) 0           activation_441[0][0]
# __________________________________________________________________________________________________
# add_186 (Add)                   (None, 256, 256, 16) 0           activation_442[0][0]
#                                                                  tf.__operators__.getitem_322[0][0
# __________________________________________________________________________________________________
# conv2d_479 (Conv2D)             (None, 256, 256, 16) 2320        add_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_485 (BatchN (None, 256, 256, 16) 64          conv2d_479[0][0]
# __________________________________________________________________________________________________
# activation_443 (Activation)     (None, 256, 256, 16) 0           batch_normalization_485[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_323 (S (None, 256, 256, 16) 0           activation_441[0][0]
# __________________________________________________________________________________________________
# add_187 (Add)                   (None, 256, 256, 16) 0           activation_443[0][0]
#                                                                  tf.__operators__.getitem_323[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_320 (S (None, 256, 256, 16) 0           activation_441[0][0]
# __________________________________________________________________________________________________
# conv2d_480 (Conv2D)             (None, 256, 256, 16) 2320        add_187[0][0]
# __________________________________________________________________________________________________
# concatenate_352 (Concatenate)   (None, 256, 256, 32) 0           tf.__operators__.getitem_320[0][0
#                                                                  activation_442[0][0]
# __________________________________________________________________________________________________
# batch_normalization_486 (BatchN (None, 256, 256, 16) 64          conv2d_480[0][0]
# __________________________________________________________________________________________________
# concatenate_353 (Concatenate)   (None, 256, 256, 48) 0           concatenate_352[0][0]
#                                                                  activation_443[0][0]
# __________________________________________________________________________________________________
# activation_444 (Activation)     (None, 256, 256, 16) 0           batch_normalization_486[0][0]
# __________________________________________________________________________________________________
# concatenate_354 (Concatenate)   (None, 256, 256, 64) 0           concatenate_353[0][0]
#                                                                  activation_444[0][0]
# __________________________________________________________________________________________________
# conv2d_481 (Conv2D)             (None, 256, 256, 64) 4160        concatenate_354[0][0]
# __________________________________________________________________________________________________
# batch_normalization_487 (BatchN (None, 256, 256, 64) 256         conv2d_481[0][0]
# __________________________________________________________________________________________________
# activation_445 (Activation)     (None, 256, 256, 64) 0           batch_normalization_487[0][0]
# __________________________________________________________________________________________________
# concatenate_355 (Concatenate)   (None, 256, 256, 128 0           activation_445[0][0]
#                                                                  activation_440[0][0]
# __________________________________________________________________________________________________
# conv2d_482 (Conv2D)             (None, 128, 128, 128 16512       concatenate_355[0][0]
# __________________________________________________________________________________________________
# batch_normalization_488 (BatchN (None, 128, 128, 128 512         conv2d_482[0][0]
# __________________________________________________________________________________________________
# activation_446 (Activation)     (None, 128, 128, 128 0           batch_normalization_488[0][0]
# __________________________________________________________________________________________________
# conv2d_483 (Conv2D)             (None, 128, 128, 128 16512       activation_446[0][0]
# __________________________________________________________________________________________________
# batch_normalization_489 (BatchN (None, 128, 128, 128 512         conv2d_483[0][0]
# __________________________________________________________________________________________________
# activation_447 (Activation)     (None, 128, 128, 128 0           batch_normalization_489[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_325 (S (None, 128, 128, 32) 0           activation_447[0][0]
# __________________________________________________________________________________________________
# conv2d_484 (Conv2D)             (None, 128, 128, 32) 9248        tf.__operators__.getitem_325[0][0
# __________________________________________________________________________________________________
# batch_normalization_490 (BatchN (None, 128, 128, 32) 128         conv2d_484[0][0]
# __________________________________________________________________________________________________
# activation_448 (Activation)     (None, 128, 128, 32) 0           batch_normalization_490[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_326 (S (None, 128, 128, 32) 0           activation_447[0][0]
# __________________________________________________________________________________________________
# add_188 (Add)                   (None, 128, 128, 32) 0           activation_448[0][0]
#                                                                  tf.__operators__.getitem_326[0][0
# __________________________________________________________________________________________________
# conv2d_485 (Conv2D)             (None, 128, 128, 32) 9248        add_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_491 (BatchN (None, 128, 128, 32) 128         conv2d_485[0][0]
# __________________________________________________________________________________________________
# activation_449 (Activation)     (None, 128, 128, 32) 0           batch_normalization_491[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_327 (S (None, 128, 128, 32) 0           activation_447[0][0]
# __________________________________________________________________________________________________
# add_189 (Add)                   (None, 128, 128, 32) 0           activation_449[0][0]
#                                                                  tf.__operators__.getitem_327[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_324 (S (None, 128, 128, 32) 0           activation_447[0][0]
# __________________________________________________________________________________________________
# conv2d_486 (Conv2D)             (None, 128, 128, 32) 9248        add_189[0][0]
# __________________________________________________________________________________________________
# concatenate_356 (Concatenate)   (None, 128, 128, 64) 0           tf.__operators__.getitem_324[0][0
#                                                                  activation_448[0][0]
# __________________________________________________________________________________________________
# batch_normalization_492 (BatchN (None, 128, 128, 32) 128         conv2d_486[0][0]
# __________________________________________________________________________________________________
# concatenate_357 (Concatenate)   (None, 128, 128, 96) 0           concatenate_356[0][0]
#                                                                  activation_449[0][0]
# __________________________________________________________________________________________________
# activation_450 (Activation)     (None, 128, 128, 32) 0           batch_normalization_492[0][0]
# __________________________________________________________________________________________________
# concatenate_358 (Concatenate)   (None, 128, 128, 128 0           concatenate_357[0][0]
#                                                                  activation_450[0][0]
# __________________________________________________________________________________________________
# conv2d_487 (Conv2D)             (None, 128, 128, 128 16512       concatenate_358[0][0]
# __________________________________________________________________________________________________
# batch_normalization_493 (BatchN (None, 128, 128, 128 512         conv2d_487[0][0]
# __________________________________________________________________________________________________
# activation_451 (Activation)     (None, 128, 128, 128 0           batch_normalization_493[0][0]
# __________________________________________________________________________________________________
# concatenate_359 (Concatenate)   (None, 128, 128, 256 0           activation_451[0][0]
#                                                                  activation_446[0][0]
# __________________________________________________________________________________________________
# conv2d_488 (Conv2D)             (None, 64, 64, 256)  65792       concatenate_359[0][0]
# __________________________________________________________________________________________________
# batch_normalization_494 (BatchN (None, 64, 64, 256)  1024        conv2d_488[0][0]
# __________________________________________________________________________________________________
# activation_452 (Activation)     (None, 64, 64, 256)  0           batch_normalization_494[0][0]
# __________________________________________________________________________________________________
# conv2d_489 (Conv2D)             (None, 64, 64, 256)  65792       activation_452[0][0]
# __________________________________________________________________________________________________
# batch_normalization_495 (BatchN (None, 64, 64, 256)  1024        conv2d_489[0][0]
# __________________________________________________________________________________________________
# activation_453 (Activation)     (None, 64, 64, 256)  0           batch_normalization_495[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_329 (S (None, 64, 64, 64)   0           activation_453[0][0]
# __________________________________________________________________________________________________
# conv2d_490 (Conv2D)             (None, 64, 64, 64)   36928       tf.__operators__.getitem_329[0][0
# __________________________________________________________________________________________________
# batch_normalization_496 (BatchN (None, 64, 64, 64)   256         conv2d_490[0][0]
# __________________________________________________________________________________________________
# activation_454 (Activation)     (None, 64, 64, 64)   0           batch_normalization_496[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_330 (S (None, 64, 64, 64)   0           activation_453[0][0]
# __________________________________________________________________________________________________
# add_190 (Add)                   (None, 64, 64, 64)   0           activation_454[0][0]
#                                                                  tf.__operators__.getitem_330[0][0
# __________________________________________________________________________________________________
# conv2d_491 (Conv2D)             (None, 64, 64, 64)   36928       add_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_497 (BatchN (None, 64, 64, 64)   256         conv2d_491[0][0]
# __________________________________________________________________________________________________
# activation_455 (Activation)     (None, 64, 64, 64)   0           batch_normalization_497[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_331 (S (None, 64, 64, 64)   0           activation_453[0][0]
# __________________________________________________________________________________________________
# add_191 (Add)                   (None, 64, 64, 64)   0           activation_455[0][0]
#                                                                  tf.__operators__.getitem_331[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_328 (S (None, 64, 64, 64)   0           activation_453[0][0]
# __________________________________________________________________________________________________
# conv2d_492 (Conv2D)             (None, 64, 64, 64)   36928       add_191[0][0]
# __________________________________________________________________________________________________
# concatenate_360 (Concatenate)   (None, 64, 64, 128)  0           tf.__operators__.getitem_328[0][0
#                                                                  activation_454[0][0]
# __________________________________________________________________________________________________
# batch_normalization_498 (BatchN (None, 64, 64, 64)   256         conv2d_492[0][0]
# __________________________________________________________________________________________________
# concatenate_361 (Concatenate)   (None, 64, 64, 192)  0           concatenate_360[0][0]
#                                                                  activation_455[0][0]
# __________________________________________________________________________________________________
# activation_456 (Activation)     (None, 64, 64, 64)   0           batch_normalization_498[0][0]
# __________________________________________________________________________________________________
# concatenate_362 (Concatenate)   (None, 64, 64, 256)  0           concatenate_361[0][0]
#                                                                  activation_456[0][0]
# __________________________________________________________________________________________________
# conv2d_493 (Conv2D)             (None, 64, 64, 256)  65792       concatenate_362[0][0]
# __________________________________________________________________________________________________
# batch_normalization_499 (BatchN (None, 64, 64, 256)  1024        conv2d_493[0][0]
# __________________________________________________________________________________________________
# activation_457 (Activation)     (None, 64, 64, 256)  0           batch_normalization_499[0][0]
# __________________________________________________________________________________________________
# concatenate_363 (Concatenate)   (None, 64, 64, 512)  0           activation_457[0][0]
#                                                                  activation_452[0][0]
# __________________________________________________________________________________________________
# conv2d_494 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_363[0][0]
# __________________________________________________________________________________________________
# batch_normalization_500 (BatchN (None, 32, 32, 512)  2048        conv2d_494[0][0]
# __________________________________________________________________________________________________
# activation_458 (Activation)     (None, 32, 32, 512)  0           batch_normalization_500[0][0]
# __________________________________________________________________________________________________
# conv2d_495 (Conv2D)             (None, 32, 32, 512)  262656      activation_458[0][0]
# __________________________________________________________________________________________________
# batch_normalization_501 (BatchN (None, 32, 32, 512)  2048        conv2d_495[0][0]
# __________________________________________________________________________________________________
# activation_459 (Activation)     (None, 32, 32, 512)  0           batch_normalization_501[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_333 (S (None, 32, 32, 128)  0           activation_459[0][0]
# __________________________________________________________________________________________________
# conv2d_496 (Conv2D)             (None, 32, 32, 128)  147584      tf.__operators__.getitem_333[0][0
# __________________________________________________________________________________________________
# batch_normalization_502 (BatchN (None, 32, 32, 128)  512         conv2d_496[0][0]
# __________________________________________________________________________________________________
# activation_460 (Activation)     (None, 32, 32, 128)  0           batch_normalization_502[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_334 (S (None, 32, 32, 128)  0           activation_459[0][0]
# __________________________________________________________________________________________________
# add_192 (Add)                   (None, 32, 32, 128)  0           activation_460[0][0]
#                                                                  tf.__operators__.getitem_334[0][0
# __________________________________________________________________________________________________
# conv2d_497 (Conv2D)             (None, 32, 32, 128)  147584      add_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_503 (BatchN (None, 32, 32, 128)  512         conv2d_497[0][0]
# __________________________________________________________________________________________________
# activation_461 (Activation)     (None, 32, 32, 128)  0           batch_normalization_503[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_335 (S (None, 32, 32, 128)  0           activation_459[0][0]
# __________________________________________________________________________________________________
# add_193 (Add)                   (None, 32, 32, 128)  0           activation_461[0][0]
#                                                                  tf.__operators__.getitem_335[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_332 (S (None, 32, 32, 128)  0           activation_459[0][0]
# __________________________________________________________________________________________________
# conv2d_498 (Conv2D)             (None, 32, 32, 128)  147584      add_193[0][0]
# __________________________________________________________________________________________________
# concatenate_364 (Concatenate)   (None, 32, 32, 256)  0           tf.__operators__.getitem_332[0][0
#                                                                  activation_460[0][0]
# __________________________________________________________________________________________________
# batch_normalization_504 (BatchN (None, 32, 32, 128)  512         conv2d_498[0][0]
# __________________________________________________________________________________________________
# concatenate_365 (Concatenate)   (None, 32, 32, 384)  0           concatenate_364[0][0]
#                                                                  activation_461[0][0]
# __________________________________________________________________________________________________
# activation_462 (Activation)     (None, 32, 32, 128)  0           batch_normalization_504[0][0]
# __________________________________________________________________________________________________
# concatenate_366 (Concatenate)   (None, 32, 32, 512)  0           concatenate_365[0][0]
#                                                                  activation_462[0][0]
# __________________________________________________________________________________________________
# conv2d_499 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_366[0][0]
# __________________________________________________________________________________________________
# batch_normalization_505 (BatchN (None, 32, 32, 512)  2048        conv2d_499[0][0]
# __________________________________________________________________________________________________
# activation_463 (Activation)     (None, 32, 32, 512)  0           batch_normalization_505[0][0]
# __________________________________________________________________________________________________
# concatenate_367 (Concatenate)   (None, 32, 32, 1024) 0           activation_463[0][0]
#                                                                  activation_458[0][0]
# __________________________________________________________________________________________________
# batch_normalization_506 (BatchN (None, 32, 32, 1024) 4096        concatenate_367[0][0]
# __________________________________________________________________________________________________
# activation_464 (Activation)     (None, 32, 32, 1024) 0           batch_normalization_506[0][0]
# __________________________________________________________________________________________________
# conv2d_500 (Conv2D)             (None, 16, 16, 1024) 9438208     activation_464[0][0]
# __________________________________________________________________________________________________
# batch_normalization_507 (BatchN (None, 16, 16, 1024) 4096        conv2d_500[0][0]
# __________________________________________________________________________________________________
# activation_465 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_507[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 1024) 0           activation_465[0][0]
# __________________________________________________________________________________________________
# conv2d_502 (Conv2D)             (None, 16, 16, 1024) 1049600     concatenate_367[0][0]
# __________________________________________________________________________________________________
# conv2d_501 (Conv2D)             (None, 16, 16, 1024) 9438208     dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_508 (BatchN (None, 16, 16, 1024) 4096        conv2d_502[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 16, 16, 1024) 0           conv2d_501[0][0]
# __________________________________________________________________________________________________
# add_194 (Add)                   (None, 16, 16, 1024) 0           batch_normalization_508[0][0]
#                                                                  lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_503 (Conv2D)             (None, 16, 16, 1024) 1049600     add_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_509 (BatchN (None, 16, 16, 1024) 4096        conv2d_503[0][0]
# __________________________________________________________________________________________________
# activation_466 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_509[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_337 (S (None, 16, 16, 128)  0           activation_466[0][0]
# __________________________________________________________________________________________________
# conv2d_504 (Conv2D)             (None, 16, 16, 128)  147584      tf.__operators__.getitem_337[0][0
# __________________________________________________________________________________________________
# batch_normalization_510 (BatchN (None, 16, 16, 128)  512         conv2d_504[0][0]
# __________________________________________________________________________________________________
# activation_467 (Activation)     (None, 16, 16, 128)  0           batch_normalization_510[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_338 (S (None, 16, 16, 128)  0           activation_466[0][0]
# __________________________________________________________________________________________________
# add_195 (Add)                   (None, 16, 16, 128)  0           activation_467[0][0]
#                                                                  tf.__operators__.getitem_338[0][0
# __________________________________________________________________________________________________
# conv2d_505 (Conv2D)             (None, 16, 16, 128)  147584      add_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_511 (BatchN (None, 16, 16, 128)  512         conv2d_505[0][0]
# __________________________________________________________________________________________________
# activation_468 (Activation)     (None, 16, 16, 128)  0           batch_normalization_511[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_339 (S (None, 16, 16, 128)  0           activation_466[0][0]
# __________________________________________________________________________________________________
# add_196 (Add)                   (None, 16, 16, 128)  0           activation_468[0][0]
#                                                                  tf.__operators__.getitem_339[0][0
# __________________________________________________________________________________________________
# conv2d_506 (Conv2D)             (None, 16, 16, 128)  147584      add_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_512 (BatchN (None, 16, 16, 128)  512         conv2d_506[0][0]
# __________________________________________________________________________________________________
# activation_469 (Activation)     (None, 16, 16, 128)  0           batch_normalization_512[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_340 (S (None, 16, 16, 128)  0           activation_466[0][0]
# __________________________________________________________________________________________________
# add_197 (Add)                   (None, 16, 16, 128)  0           activation_469[0][0]
#                                                                  tf.__operators__.getitem_340[0][0
# __________________________________________________________________________________________________
# conv2d_507 (Conv2D)             (None, 16, 16, 128)  147584      add_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_513 (BatchN (None, 16, 16, 128)  512         conv2d_507[0][0]
# __________________________________________________________________________________________________
# activation_470 (Activation)     (None, 16, 16, 128)  0           batch_normalization_513[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_341 (S (None, 16, 16, 128)  0           activation_466[0][0]
# __________________________________________________________________________________________________
# add_198 (Add)                   (None, 16, 16, 128)  0           activation_470[0][0]
#                                                                  tf.__operators__.getitem_341[0][0
# __________________________________________________________________________________________________
# conv2d_508 (Conv2D)             (None, 16, 16, 128)  147584      add_198[0][0]
# __________________________________________________________________________________________________
# batch_normalization_514 (BatchN (None, 16, 16, 128)  512         conv2d_508[0][0]
# __________________________________________________________________________________________________
# activation_471 (Activation)     (None, 16, 16, 128)  0           batch_normalization_514[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_342 (S (None, 16, 16, 128)  0           activation_466[0][0]
# __________________________________________________________________________________________________
# add_199 (Add)                   (None, 16, 16, 128)  0           activation_471[0][0]
#                                                                  tf.__operators__.getitem_342[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_336 (S (None, 16, 16, 128)  0           activation_466[0][0]
# __________________________________________________________________________________________________
# conv2d_509 (Conv2D)             (None, 16, 16, 128)  147584      add_199[0][0]
# __________________________________________________________________________________________________
# concatenate_368 (Concatenate)   (None, 16, 16, 256)  0           tf.__operators__.getitem_336[0][0
#                                                                  activation_467[0][0]
# __________________________________________________________________________________________________
# batch_normalization_515 (BatchN (None, 16, 16, 128)  512         conv2d_509[0][0]
# __________________________________________________________________________________________________
# concatenate_369 (Concatenate)   (None, 16, 16, 384)  0           concatenate_368[0][0]
#                                                                  activation_468[0][0]
# __________________________________________________________________________________________________
# activation_472 (Activation)     (None, 16, 16, 128)  0           batch_normalization_515[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_343 (S (None, 16, 16, 128)  0           activation_466[0][0]
# __________________________________________________________________________________________________
# concatenate_370 (Concatenate)   (None, 16, 16, 512)  0           concatenate_369[0][0]
#                                                                  activation_469[0][0]
# __________________________________________________________________________________________________
# add_200 (Add)                   (None, 16, 16, 128)  0           activation_472[0][0]
#                                                                  tf.__operators__.getitem_343[0][0
# __________________________________________________________________________________________________
# concatenate_371 (Concatenate)   (None, 16, 16, 640)  0           concatenate_370[0][0]
#                                                                  activation_470[0][0]
# __________________________________________________________________________________________________
# conv2d_510 (Conv2D)             (None, 16, 16, 128)  147584      add_200[0][0]
# __________________________________________________________________________________________________
# concatenate_372 (Concatenate)   (None, 16, 16, 768)  0           concatenate_371[0][0]
#                                                                  activation_471[0][0]
# __________________________________________________________________________________________________
# batch_normalization_516 (BatchN (None, 16, 16, 128)  512         conv2d_510[0][0]
# __________________________________________________________________________________________________
# concatenate_373 (Concatenate)   (None, 16, 16, 896)  0           concatenate_372[0][0]
#                                                                  activation_472[0][0]
# __________________________________________________________________________________________________
# activation_473 (Activation)     (None, 16, 16, 128)  0           batch_normalization_516[0][0]
# __________________________________________________________________________________________________
# concatenate_374 (Concatenate)   (None, 16, 16, 1024) 0           concatenate_373[0][0]
#                                                                  activation_473[0][0]
# __________________________________________________________________________________________________
# conv2d_511 (Conv2D)             (None, 16, 16, 1024) 1049600     concatenate_374[0][0]
# __________________________________________________________________________________________________
# batch_normalization_517 (BatchN (None, 16, 16, 1024) 4096        conv2d_511[0][0]
# __________________________________________________________________________________________________
# activation_474 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_517[0][0]
# __________________________________________________________________________________________________
# concatenate_375 (Concatenate)   (None, 16, 16, 2048) 0           activation_474[0][0]
#                                                                  add_194[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_32 (Conv2DTran (None, 32, 32, 512)  4194816     concatenate_375[0][0]
# __________________________________________________________________________________________________
# batch_normalization_518 (BatchN (None, 32, 32, 512)  2048        conv2d_transpose_32[0][0]
# __________________________________________________________________________________________________
# concatenate_376 (Concatenate)   (None, 32, 32, 1536) 0           batch_normalization_518[0][0]
#                                                                  concatenate_367[0][0]
# __________________________________________________________________________________________________
# conv2d_512 (Conv2D)             (None, 32, 32, 512)  786944      concatenate_376[0][0]
# __________________________________________________________________________________________________
# batch_normalization_519 (BatchN (None, 32, 32, 512)  2048        conv2d_512[0][0]
# __________________________________________________________________________________________________
# activation_475 (Activation)     (None, 32, 32, 512)  0           batch_normalization_519[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_345 (S (None, 32, 32, 128)  0           activation_475[0][0]
# __________________________________________________________________________________________________
# conv2d_513 (Conv2D)             (None, 32, 32, 128)  147584      tf.__operators__.getitem_345[0][0
# __________________________________________________________________________________________________
# batch_normalization_520 (BatchN (None, 32, 32, 128)  512         conv2d_513[0][0]
# __________________________________________________________________________________________________
# activation_476 (Activation)     (None, 32, 32, 128)  0           batch_normalization_520[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_346 (S (None, 32, 32, 128)  0           activation_475[0][0]
# __________________________________________________________________________________________________
# add_201 (Add)                   (None, 32, 32, 128)  0           activation_476[0][0]
#                                                                  tf.__operators__.getitem_346[0][0
# __________________________________________________________________________________________________
# conv2d_514 (Conv2D)             (None, 32, 32, 128)  147584      add_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_521 (BatchN (None, 32, 32, 128)  512         conv2d_514[0][0]
# __________________________________________________________________________________________________
# activation_477 (Activation)     (None, 32, 32, 128)  0           batch_normalization_521[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_347 (S (None, 32, 32, 128)  0           activation_475[0][0]
# __________________________________________________________________________________________________
# add_202 (Add)                   (None, 32, 32, 128)  0           activation_477[0][0]
#                                                                  tf.__operators__.getitem_347[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_344 (S (None, 32, 32, 128)  0           activation_475[0][0]
# __________________________________________________________________________________________________
# conv2d_515 (Conv2D)             (None, 32, 32, 128)  147584      add_202[0][0]
# __________________________________________________________________________________________________
# concatenate_377 (Concatenate)   (None, 32, 32, 256)  0           tf.__operators__.getitem_344[0][0
#                                                                  activation_476[0][0]
# __________________________________________________________________________________________________
# batch_normalization_522 (BatchN (None, 32, 32, 128)  512         conv2d_515[0][0]
# __________________________________________________________________________________________________
# concatenate_378 (Concatenate)   (None, 32, 32, 384)  0           concatenate_377[0][0]
#                                                                  activation_477[0][0]
# __________________________________________________________________________________________________
# activation_478 (Activation)     (None, 32, 32, 128)  0           batch_normalization_522[0][0]
# __________________________________________________________________________________________________
# concatenate_379 (Concatenate)   (None, 32, 32, 512)  0           concatenate_378[0][0]
#                                                                  activation_478[0][0]
# __________________________________________________________________________________________________
# conv2d_516 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_379[0][0]
# __________________________________________________________________________________________________
# batch_normalization_523 (BatchN (None, 32, 32, 512)  2048        conv2d_516[0][0]
# __________________________________________________________________________________________________
# activation_479 (Activation)     (None, 32, 32, 512)  0           batch_normalization_523[0][0]
# __________________________________________________________________________________________________
# concatenate_380 (Concatenate)   (None, 32, 32, 2048) 0           activation_479[0][0]
#                                                                  concatenate_376[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_33 (Conv2DTran (None, 64, 64, 256)  2097408     concatenate_380[0][0]
# __________________________________________________________________________________________________
# batch_normalization_524 (BatchN (None, 64, 64, 256)  1024        conv2d_transpose_33[0][0]
# __________________________________________________________________________________________________
# concatenate_381 (Concatenate)   (None, 64, 64, 768)  0           batch_normalization_524[0][0]
#                                                                  concatenate_363[0][0]
# __________________________________________________________________________________________________
# conv2d_517 (Conv2D)             (None, 64, 64, 256)  196864      concatenate_381[0][0]
# __________________________________________________________________________________________________
# batch_normalization_525 (BatchN (None, 64, 64, 256)  1024        conv2d_517[0][0]
# __________________________________________________________________________________________________
# activation_480 (Activation)     (None, 64, 64, 256)  0           batch_normalization_525[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_349 (S (None, 64, 64, 64)   0           activation_480[0][0]
# __________________________________________________________________________________________________
# conv2d_518 (Conv2D)             (None, 64, 64, 64)   36928       tf.__operators__.getitem_349[0][0
# __________________________________________________________________________________________________
# batch_normalization_526 (BatchN (None, 64, 64, 64)   256         conv2d_518[0][0]
# __________________________________________________________________________________________________
# activation_481 (Activation)     (None, 64, 64, 64)   0           batch_normalization_526[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_350 (S (None, 64, 64, 64)   0           activation_480[0][0]
# __________________________________________________________________________________________________
# add_203 (Add)                   (None, 64, 64, 64)   0           activation_481[0][0]
#                                                                  tf.__operators__.getitem_350[0][0
# __________________________________________________________________________________________________
# conv2d_519 (Conv2D)             (None, 64, 64, 64)   36928       add_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_527 (BatchN (None, 64, 64, 64)   256         conv2d_519[0][0]
# __________________________________________________________________________________________________
# activation_482 (Activation)     (None, 64, 64, 64)   0           batch_normalization_527[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_351 (S (None, 64, 64, 64)   0           activation_480[0][0]
# ...
# add_207 (Add)                   (None, 256, 256, 16) 0           activation_491[0][0]
#                                                                  tf.__operators__.getitem_358[0][0
# __________________________________________________________________________________________________
# conv2d_529 (Conv2D)             (None, 256, 256, 16) 2320        add_207[0][0]
# __________________________________________________________________________________________________
# batch_normalization_539 (BatchN (None, 256, 256, 16) 64          conv2d_529[0][0]
# __________________________________________________________________________________________________
# activation_492 (Activation)     (None, 256, 256, 16) 0           batch_normalization_539[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_359 (S (None, 256, 256, 16) 0           activation_490[0][0]
# __________________________________________________________________________________________________
# add_208 (Add)                   (None, 256, 256, 16) 0           activation_492[0][0]
#                                                                  tf.__operators__.getitem_359[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_356 (S (None, 256, 256, 16) 0           activation_490[0][0]
# __________________________________________________________________________________________________
# conv2d_530 (Conv2D)             (None, 256, 256, 16) 2320        add_208[0][0]
# __________________________________________________________________________________________________
# concatenate_392 (Concatenate)   (None, 256, 256, 32) 0           tf.__operators__.getitem_356[0][0
#                                                                  activation_491[0][0]
# __________________________________________________________________________________________________
# batch_normalization_540 (BatchN (None, 256, 256, 16) 64          conv2d_530[0][0]
# __________________________________________________________________________________________________
# concatenate_393 (Concatenate)   (None, 256, 256, 48) 0           concatenate_392[0][0]
#                                                                  activation_492[0][0]
# __________________________________________________________________________________________________
# activation_493 (Activation)     (None, 256, 256, 16) 0           batch_normalization_540[0][0]
# __________________________________________________________________________________________________
# concatenate_394 (Concatenate)   (None, 256, 256, 64) 0           concatenate_393[0][0]
#                                                                  activation_493[0][0]
# __________________________________________________________________________________________________
# conv2d_531 (Conv2D)             (None, 256, 256, 64) 4160        concatenate_394[0][0]
# __________________________________________________________________________________________________
# batch_normalization_541 (BatchN (None, 256, 256, 64) 256         conv2d_531[0][0]
# __________________________________________________________________________________________________
# activation_494 (Activation)     (None, 256, 256, 64) 0           batch_normalization_541[0][0]
# __________________________________________________________________________________________________
# concatenate_395 (Concatenate)   (None, 256, 256, 256 0           activation_494[0][0]
#                                                                  concatenate_391[0][0]
# __________________________________________________________________________________________________
# conv2d_532 (Conv2D)             (None, 256, 256, 64) 147520      concatenate_395[0][0]
# __________________________________________________________________________________________________
# conv2d_533 (Conv2D)             (None, 256, 256, 2)  1154        conv2d_532[0][0]
# __________________________________________________________________________________________________
# conv2d_534 (Conv2D)             (None, 256, 256, 1)  3           conv2d_533[0][0]
# ==================================================================================================
# Total params: 33,823,653
# Trainable params: 33,797,221
# Non-trainable params: 26,432
# __________________________________________________________________________________________________
# Epoch 1/25
# (None, 256, 256, 1)
# (None, 256, 256, 1)
# (None, 256, 256, 1)
# (None, 256, 256, 1)
# 1912/1912 [==============================] - ETA: 0s - loss: 3296.3297 - ACL5: 3296.3297 - binary_crossentropy_plus_jaccard_loss: 0.3243 - dice_loss: 0.1724 - iou_coeff: 0.7134 - precision: 0.8638 - recall: 0.8055(None, 256, 256, 1)
# (None, 256, 256, 1)
# 1912/1912 [==============================] - 280s 142ms/step - loss: 3296.3526 - ACL5: 3296.3526 - binary_crossentropy_plus_jaccard_loss: 0.3244 - dice_loss: 0.1724 - iou_coeff: 0.7134 - precision: 0.8638 - recall: 0.8055 - val_loss: 2154.0557 - val_ACL5: 2154.0557 - val_binary_crossentropy_plus_jaccard_loss: 0.4853 - val_dice_loss: 0.2759 - val_iou_coeff: 0.6211 - val_precision: 0.7716 - val_recall: 0.6492
#
# Epoch 00001: val_dice_loss did not improve from 0.22550
# Epoch 2/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 3373.7507 - ACL5: 3373.7507 - binary_crossentropy_plus_jaccard_loss: 0.3459 - dice_loss: 0.1806 - iou_coeff: 0.7036 - precision: 0.8595 - recall: 0.7961 - val_loss: 14313.5146 - val_ACL5: 14313.5146 - val_binary_crossentropy_plus_jaccard_loss: 1.0217 - val_dice_loss: 0.5209 - val_iou_coeff: 0.3591 - val_precision: 0.4138 - val_recall: 0.7360
#
# Epoch 00002: val_dice_loss did not improve from 0.22550
# Epoch 3/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 3330.5743 - ACL5: 3330.5743 - binary_crossentropy_plus_jaccard_loss: 0.3412 - dice_loss: 0.1748 - iou_coeff: 0.7111 - precision: 0.8633 - recall: 0.8011 - val_loss: 2071.7268 - val_ACL5: 2071.7268 - val_binary_crossentropy_plus_jaccard_loss: 0.4730 - val_dice_loss: 0.2664 - val_iou_coeff: 0.6259 - val_precision: 0.7680 - val_recall: 0.6917
#
# Epoch 00003: val_dice_loss did not improve from 0.22550
# Epoch 4/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 3285.6715 - ACL5: 3285.6715 - binary_crossentropy_plus_jaccard_loss: 0.3477 - dice_loss: 0.1760 - iou_coeff: 0.7096 - precision: 0.8599 - recall: 0.7965 - val_loss: 2325.9045 - val_ACL5: 2325.9045 - val_binary_crossentropy_plus_jaccard_loss: 0.5227 - val_dice_loss: 0.2980 - val_iou_coeff: 0.5955 - val_precision: 0.7528 - val_recall: 0.6523
#
# Epoch 00004: val_dice_loss did not improve from 0.22550
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.4000000373926015e-05.
# Epoch 5/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 3127.0266 - ACL5: 3127.0266 - binary_crossentropy_plus_jaccard_loss: 0.3333 - dice_loss: 0.1709 - iou_coeff: 0.7194 - precision: 0.8630 - recall: 0.8052 - val_loss: 1808.7838 - val_ACL5: 1808.7838 - val_binary_crossentropy_plus_jaccard_loss: 0.4273 - val_dice_loss: 0.2219 - val_iou_coeff: 0.6741 - val_precision: 0.8039 - val_recall: 0.7098
#
# Epoch 00005: val_dice_loss improved from 0.22550 to 0.22185, saving model to Res2Net.hdf5
# Epoch 6/25
# 1912/1912 [==============================] - 270s 141ms/step - loss: 3014.1369 - ACL5: 3014.1369 - binary_crossentropy_plus_jaccard_loss: 0.3152 - dice_loss: 0.1575 - iou_coeff: 0.7344 - precision: 0.8748 - recall: 0.8195 - val_loss: 1877.7461 - val_ACL5: 1877.7461 - val_binary_crossentropy_plus_jaccard_loss: 0.4548 - val_dice_loss: 0.2388 - val_iou_coeff: 0.6585 - val_precision: 0.8029 - val_recall: 0.6823
#
# Epoch 00006: val_dice_loss did not improve from 0.22185
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 2.8000000384054148e-06.
# Epoch 7/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 2958.3464 - ACL5: 2958.3464 - binary_crossentropy_plus_jaccard_loss: 0.3098 - dice_loss: 0.1543 - iou_coeff: 0.7394 - precision: 0.8752 - recall: 0.8232 - val_loss: 1843.9934 - val_ACL5: 1843.9934 - val_binary_crossentropy_plus_jaccard_loss: 0.4344 - val_dice_loss: 0.2282 - val_iou_coeff: 0.6685 - val_precision: 0.8058 - val_recall: 0.7083
#
# Epoch 00007: val_dice_loss did not improve from 0.22185
# Epoch 8/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 2931.7279 - ACL5: 2931.7279 - binary_crossentropy_plus_jaccard_loss: 0.3029 - dice_loss: 0.1497 - iou_coeff: 0.7448 - precision: 0.8786 - recall: 0.8299 - val_loss: 1824.9183 - val_ACL5: 1824.9183 - val_binary_crossentropy_plus_jaccard_loss: 0.4281 - val_dice_loss: 0.2260 - val_iou_coeff: 0.6707 - val_precision: 0.8136 - val_recall: 0.7152
#
# Epoch 00008: val_dice_loss did not improve from 0.22185
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 5.599999894911889e-07.
# Epoch 9/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 2947.6088 - ACL5: 2947.6088 - binary_crossentropy_plus_jaccard_loss: 0.3071 - dice_loss: 0.1517 - iou_coeff: 0.7419 - precision: 0.8790 - recall: 0.8249 - val_loss: 1842.1718 - val_ACL5: 1842.1718 - val_binary_crossentropy_plus_jaccard_loss: 0.4337 - val_dice_loss: 0.2249 - val_iou_coeff: 0.6704 - val_precision: 0.8088 - val_recall: 0.7086
#
# Epoch 00009: val_dice_loss did not improve from 0.22185
# Epoch 10/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 2933.0128 - ACL5: 2933.0128 - binary_crossentropy_plus_jaccard_loss: 0.3028 - dice_loss: 0.1491 - iou_coeff: 0.7455 - precision: 0.8802 - recall: 0.8280 - val_loss: 1820.4979 - val_ACL5: 1820.4979 - val_binary_crossentropy_plus_jaccard_loss: 0.4289 - val_dice_loss: 0.2307 - val_iou_coeff: 0.6658 - val_precision: 0.8216 - val_recall: 0.7121
#
# Epoch 00010: val_dice_loss did not improve from 0.22185
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.1199999789823778e-07.
# Epoch 11/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 2925.3290 - ACL5: 2925.3290 - binary_crossentropy_plus_jaccard_loss: 0.3027 - dice_loss: 0.1495 - iou_coeff: 0.7453 - precision: 0.8807 - recall: 0.8276 - val_loss: 1849.4026 - val_ACL5: 1849.4026 - val_binary_crossentropy_plus_jaccard_loss: 0.4443 - val_dice_loss: 0.2280 - val_iou_coeff: 0.6697 - val_precision: 0.8002 - val_recall: 0.6945
#
# Epoch 00011: val_dice_loss did not improve from 0.22185
# Epoch 12/25
# 1912/1912 [==============================] - 271s 142ms/step - loss: 2894.9500 - ACL5: 2894.9500 - binary_crossentropy_plus_jaccard_loss: 0.3009 - dice_loss: 0.1488 - iou_coeff: 0.7459 - precision: 0.8812 - recall: 0.8288 - val_loss: 1815.1167 - val_ACL5: 1815.1167 - val_binary_crossentropy_plus_jaccard_loss: 0.4297 - val_dice_loss: 0.2329 - val_iou_coeff: 0.6653 - val_precision: 0.8035 - val_recall: 0.7141
#
# Epoch 00012: val_dice_loss did not improve from 0.22185
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 13/25
# 1912/1912 [==============================] - 270s 141ms/step - loss: 2921.3145 - ACL5: 2921.3145 - binary_crossentropy_plus_jaccard_loss: 0.3045 - dice_loss: 0.1499 - iou_coeff: 0.7453 - precision: 0.8767 - recall: 0.8262 - val_loss: 1832.9435 - val_ACL5: 1832.9435 - val_binary_crossentropy_plus_jaccard_loss: 0.4298 - val_dice_loss: 0.2312 - val_iou_coeff: 0.6662 - val_precision: 0.8141 - val_recall: 0.7107
#
# Epoch 00013: val_dice_loss did not improve from 0.22185
# Epoch 14/25
#  397/1912 [=====>........................] - ETA: 3:27 - loss: 3010.3347 - ACL5: 3010.3347 - binary_crossentropy_plus_jaccard_loss: 0.3139 - dice_loss: 0.1564 - iou_coeff: 0.7394 - precision: 0.8707 - recall: 0.8161
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-6344185ebc01> in <module>
#       6                               validation_steps=207,
#       7                               validation_data=valid_data,
# ----> 8                               callbacks=[model_checkpoint1,csv_logger , learning_rate_reduction])
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1859         use_multiprocessing=use_multiprocessing,
#    1860         shuffle=shuffle,
# -> 1861         initial_epoch=initial_epoch)
#    1862
#    1863   def evaluate_generator(self,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model = res2unet(lrate=7.00E-05 , pretrained_weights = './Res2Net.hdf5')


history = model.fit_generator(train_data,
                              steps_per_epoch=1912,epochs=25,
                              validation_steps=207,
                              validation_data=valid_data,
                              callbacks=[model_checkpoint1,csv_logger ])
# Out:
# 7e-05
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_535 (Conv2D)             (None, 256, 256, 64) 1792        input_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_542 (BatchN (None, 256, 256, 64) 256         conv2d_535[0][0]
# __________________________________________________________________________________________________
# activation_495 (Activation)     (None, 256, 256, 64) 0           batch_normalization_542[0][0]
# __________________________________________________________________________________________________
# conv2d_536 (Conv2D)             (None, 256, 256, 64) 4160        activation_495[0][0]
# __________________________________________________________________________________________________
# batch_normalization_543 (BatchN (None, 256, 256, 64) 256         conv2d_536[0][0]
# __________________________________________________________________________________________________
# activation_496 (Activation)     (None, 256, 256, 64) 0           batch_normalization_543[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_361 (S (None, 256, 256, 16) 0           activation_496[0][0]
# __________________________________________________________________________________________________
# conv2d_537 (Conv2D)             (None, 256, 256, 16) 2320        tf.__operators__.getitem_361[0][0
# __________________________________________________________________________________________________
# batch_normalization_544 (BatchN (None, 256, 256, 16) 64          conv2d_537[0][0]
# __________________________________________________________________________________________________
# activation_497 (Activation)     (None, 256, 256, 16) 0           batch_normalization_544[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_362 (S (None, 256, 256, 16) 0           activation_496[0][0]
# __________________________________________________________________________________________________
# add_209 (Add)                   (None, 256, 256, 16) 0           activation_497[0][0]
#                                                                  tf.__operators__.getitem_362[0][0
# __________________________________________________________________________________________________
# conv2d_538 (Conv2D)             (None, 256, 256, 16) 2320        add_209[0][0]
# __________________________________________________________________________________________________
# batch_normalization_545 (BatchN (None, 256, 256, 16) 64          conv2d_538[0][0]
# __________________________________________________________________________________________________
# activation_498 (Activation)     (None, 256, 256, 16) 0           batch_normalization_545[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_363 (S (None, 256, 256, 16) 0           activation_496[0][0]
# __________________________________________________________________________________________________
# add_210 (Add)                   (None, 256, 256, 16) 0           activation_498[0][0]
#                                                                  tf.__operators__.getitem_363[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_360 (S (None, 256, 256, 16) 0           activation_496[0][0]
# __________________________________________________________________________________________________
# conv2d_539 (Conv2D)             (None, 256, 256, 16) 2320        add_210[0][0]
# __________________________________________________________________________________________________
# concatenate_396 (Concatenate)   (None, 256, 256, 32) 0           tf.__operators__.getitem_360[0][0
#                                                                  activation_497[0][0]
# __________________________________________________________________________________________________
# batch_normalization_546 (BatchN (None, 256, 256, 16) 64          conv2d_539[0][0]
# __________________________________________________________________________________________________
# concatenate_397 (Concatenate)   (None, 256, 256, 48) 0           concatenate_396[0][0]
#                                                                  activation_498[0][0]
# __________________________________________________________________________________________________
# activation_499 (Activation)     (None, 256, 256, 16) 0           batch_normalization_546[0][0]
# __________________________________________________________________________________________________
# concatenate_398 (Concatenate)   (None, 256, 256, 64) 0           concatenate_397[0][0]
#                                                                  activation_499[0][0]
# __________________________________________________________________________________________________
# conv2d_540 (Conv2D)             (None, 256, 256, 64) 4160        concatenate_398[0][0]
# __________________________________________________________________________________________________
# batch_normalization_547 (BatchN (None, 256, 256, 64) 256         conv2d_540[0][0]
# __________________________________________________________________________________________________
# activation_500 (Activation)     (None, 256, 256, 64) 0           batch_normalization_547[0][0]
# __________________________________________________________________________________________________
# concatenate_399 (Concatenate)   (None, 256, 256, 128 0           activation_500[0][0]
#                                                                  activation_495[0][0]
# __________________________________________________________________________________________________
# conv2d_541 (Conv2D)             (None, 128, 128, 128 16512       concatenate_399[0][0]
# __________________________________________________________________________________________________
# batch_normalization_548 (BatchN (None, 128, 128, 128 512         conv2d_541[0][0]
# __________________________________________________________________________________________________
# activation_501 (Activation)     (None, 128, 128, 128 0           batch_normalization_548[0][0]
# __________________________________________________________________________________________________
# conv2d_542 (Conv2D)             (None, 128, 128, 128 16512       activation_501[0][0]
# __________________________________________________________________________________________________
# batch_normalization_549 (BatchN (None, 128, 128, 128 512         conv2d_542[0][0]
# __________________________________________________________________________________________________
# activation_502 (Activation)     (None, 128, 128, 128 0           batch_normalization_549[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_365 (S (None, 128, 128, 32) 0           activation_502[0][0]
# __________________________________________________________________________________________________
# conv2d_543 (Conv2D)             (None, 128, 128, 32) 9248        tf.__operators__.getitem_365[0][0
# __________________________________________________________________________________________________
# batch_normalization_550 (BatchN (None, 128, 128, 32) 128         conv2d_543[0][0]
# __________________________________________________________________________________________________
# activation_503 (Activation)     (None, 128, 128, 32) 0           batch_normalization_550[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_366 (S (None, 128, 128, 32) 0           activation_502[0][0]
# __________________________________________________________________________________________________
# add_211 (Add)                   (None, 128, 128, 32) 0           activation_503[0][0]
#                                                                  tf.__operators__.getitem_366[0][0
# __________________________________________________________________________________________________
# conv2d_544 (Conv2D)             (None, 128, 128, 32) 9248        add_211[0][0]
# __________________________________________________________________________________________________
# batch_normalization_551 (BatchN (None, 128, 128, 32) 128         conv2d_544[0][0]
# __________________________________________________________________________________________________
# activation_504 (Activation)     (None, 128, 128, 32) 0           batch_normalization_551[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_367 (S (None, 128, 128, 32) 0           activation_502[0][0]
# __________________________________________________________________________________________________
# add_212 (Add)                   (None, 128, 128, 32) 0           activation_504[0][0]
#                                                                  tf.__operators__.getitem_367[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_364 (S (None, 128, 128, 32) 0           activation_502[0][0]
# __________________________________________________________________________________________________
# conv2d_545 (Conv2D)             (None, 128, 128, 32) 9248        add_212[0][0]
# __________________________________________________________________________________________________
# concatenate_400 (Concatenate)   (None, 128, 128, 64) 0           tf.__operators__.getitem_364[0][0
#                                                                  activation_503[0][0]
# __________________________________________________________________________________________________
# batch_normalization_552 (BatchN (None, 128, 128, 32) 128         conv2d_545[0][0]
# __________________________________________________________________________________________________
# concatenate_401 (Concatenate)   (None, 128, 128, 96) 0           concatenate_400[0][0]
#                                                                  activation_504[0][0]
# __________________________________________________________________________________________________
# activation_505 (Activation)     (None, 128, 128, 32) 0           batch_normalization_552[0][0]
# __________________________________________________________________________________________________
# concatenate_402 (Concatenate)   (None, 128, 128, 128 0           concatenate_401[0][0]
#                                                                  activation_505[0][0]
# __________________________________________________________________________________________________
# conv2d_546 (Conv2D)             (None, 128, 128, 128 16512       concatenate_402[0][0]
# __________________________________________________________________________________________________
# batch_normalization_553 (BatchN (None, 128, 128, 128 512         conv2d_546[0][0]
# __________________________________________________________________________________________________
# activation_506 (Activation)     (None, 128, 128, 128 0           batch_normalization_553[0][0]
# __________________________________________________________________________________________________
# concatenate_403 (Concatenate)   (None, 128, 128, 256 0           activation_506[0][0]
#                                                                  activation_501[0][0]
# __________________________________________________________________________________________________
# conv2d_547 (Conv2D)             (None, 64, 64, 256)  65792       concatenate_403[0][0]
# __________________________________________________________________________________________________
# batch_normalization_554 (BatchN (None, 64, 64, 256)  1024        conv2d_547[0][0]
# __________________________________________________________________________________________________
# activation_507 (Activation)     (None, 64, 64, 256)  0           batch_normalization_554[0][0]
# __________________________________________________________________________________________________
# conv2d_548 (Conv2D)             (None, 64, 64, 256)  65792       activation_507[0][0]
# __________________________________________________________________________________________________
# batch_normalization_555 (BatchN (None, 64, 64, 256)  1024        conv2d_548[0][0]
# __________________________________________________________________________________________________
# activation_508 (Activation)     (None, 64, 64, 256)  0           batch_normalization_555[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_369 (S (None, 64, 64, 64)   0           activation_508[0][0]
# __________________________________________________________________________________________________
# conv2d_549 (Conv2D)             (None, 64, 64, 64)   36928       tf.__operators__.getitem_369[0][0
# __________________________________________________________________________________________________
# batch_normalization_556 (BatchN (None, 64, 64, 64)   256         conv2d_549[0][0]
# __________________________________________________________________________________________________
# activation_509 (Activation)     (None, 64, 64, 64)   0           batch_normalization_556[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_370 (S (None, 64, 64, 64)   0           activation_508[0][0]
# __________________________________________________________________________________________________
# add_213 (Add)                   (None, 64, 64, 64)   0           activation_509[0][0]
#                                                                  tf.__operators__.getitem_370[0][0
# __________________________________________________________________________________________________
# conv2d_550 (Conv2D)             (None, 64, 64, 64)   36928       add_213[0][0]
# __________________________________________________________________________________________________
# batch_normalization_557 (BatchN (None, 64, 64, 64)   256         conv2d_550[0][0]
# __________________________________________________________________________________________________
# activation_510 (Activation)     (None, 64, 64, 64)   0           batch_normalization_557[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_371 (S (None, 64, 64, 64)   0           activation_508[0][0]
# __________________________________________________________________________________________________
# add_214 (Add)                   (None, 64, 64, 64)   0           activation_510[0][0]
#                                                                  tf.__operators__.getitem_371[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_368 (S (None, 64, 64, 64)   0           activation_508[0][0]
# __________________________________________________________________________________________________
# conv2d_551 (Conv2D)             (None, 64, 64, 64)   36928       add_214[0][0]
# __________________________________________________________________________________________________
# concatenate_404 (Concatenate)   (None, 64, 64, 128)  0           tf.__operators__.getitem_368[0][0
#                                                                  activation_509[0][0]
# __________________________________________________________________________________________________
# batch_normalization_558 (BatchN (None, 64, 64, 64)   256         conv2d_551[0][0]
# __________________________________________________________________________________________________
# concatenate_405 (Concatenate)   (None, 64, 64, 192)  0           concatenate_404[0][0]
#                                                                  activation_510[0][0]
# __________________________________________________________________________________________________
# activation_511 (Activation)     (None, 64, 64, 64)   0           batch_normalization_558[0][0]
# __________________________________________________________________________________________________
# concatenate_406 (Concatenate)   (None, 64, 64, 256)  0           concatenate_405[0][0]
#                                                                  activation_511[0][0]
# __________________________________________________________________________________________________
# conv2d_552 (Conv2D)             (None, 64, 64, 256)  65792       concatenate_406[0][0]
# __________________________________________________________________________________________________
# batch_normalization_559 (BatchN (None, 64, 64, 256)  1024        conv2d_552[0][0]
# __________________________________________________________________________________________________
# activation_512 (Activation)     (None, 64, 64, 256)  0           batch_normalization_559[0][0]
# __________________________________________________________________________________________________
# concatenate_407 (Concatenate)   (None, 64, 64, 512)  0           activation_512[0][0]
#                                                                  activation_507[0][0]
# __________________________________________________________________________________________________
# conv2d_553 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_407[0][0]
# __________________________________________________________________________________________________
# batch_normalization_560 (BatchN (None, 32, 32, 512)  2048        conv2d_553[0][0]
# __________________________________________________________________________________________________
# activation_513 (Activation)     (None, 32, 32, 512)  0           batch_normalization_560[0][0]
# __________________________________________________________________________________________________
# conv2d_554 (Conv2D)             (None, 32, 32, 512)  262656      activation_513[0][0]
# __________________________________________________________________________________________________
# batch_normalization_561 (BatchN (None, 32, 32, 512)  2048        conv2d_554[0][0]
# __________________________________________________________________________________________________
# activation_514 (Activation)     (None, 32, 32, 512)  0           batch_normalization_561[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_373 (S (None, 32, 32, 128)  0           activation_514[0][0]
# __________________________________________________________________________________________________
# conv2d_555 (Conv2D)             (None, 32, 32, 128)  147584      tf.__operators__.getitem_373[0][0
# __________________________________________________________________________________________________
# batch_normalization_562 (BatchN (None, 32, 32, 128)  512         conv2d_555[0][0]
# __________________________________________________________________________________________________
# activation_515 (Activation)     (None, 32, 32, 128)  0           batch_normalization_562[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_374 (S (None, 32, 32, 128)  0           activation_514[0][0]
# __________________________________________________________________________________________________
# add_215 (Add)                   (None, 32, 32, 128)  0           activation_515[0][0]
#                                                                  tf.__operators__.getitem_374[0][0
# __________________________________________________________________________________________________
# conv2d_556 (Conv2D)             (None, 32, 32, 128)  147584      add_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_563 (BatchN (None, 32, 32, 128)  512         conv2d_556[0][0]
# __________________________________________________________________________________________________
# activation_516 (Activation)     (None, 32, 32, 128)  0           batch_normalization_563[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_375 (S (None, 32, 32, 128)  0           activation_514[0][0]
# __________________________________________________________________________________________________
# add_216 (Add)                   (None, 32, 32, 128)  0           activation_516[0][0]
#                                                                  tf.__operators__.getitem_375[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_372 (S (None, 32, 32, 128)  0           activation_514[0][0]
# __________________________________________________________________________________________________
# conv2d_557 (Conv2D)             (None, 32, 32, 128)  147584      add_216[0][0]
# __________________________________________________________________________________________________
# concatenate_408 (Concatenate)   (None, 32, 32, 256)  0           tf.__operators__.getitem_372[0][0
#                                                                  activation_515[0][0]
# __________________________________________________________________________________________________
# batch_normalization_564 (BatchN (None, 32, 32, 128)  512         conv2d_557[0][0]
# __________________________________________________________________________________________________
# concatenate_409 (Concatenate)   (None, 32, 32, 384)  0           concatenate_408[0][0]
#                                                                  activation_516[0][0]
# __________________________________________________________________________________________________
# activation_517 (Activation)     (None, 32, 32, 128)  0           batch_normalization_564[0][0]
# __________________________________________________________________________________________________
# concatenate_410 (Concatenate)   (None, 32, 32, 512)  0           concatenate_409[0][0]
#                                                                  activation_517[0][0]
# __________________________________________________________________________________________________
# conv2d_558 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_410[0][0]
# __________________________________________________________________________________________________
# batch_normalization_565 (BatchN (None, 32, 32, 512)  2048        conv2d_558[0][0]
# __________________________________________________________________________________________________
# activation_518 (Activation)     (None, 32, 32, 512)  0           batch_normalization_565[0][0]
# __________________________________________________________________________________________________
# concatenate_411 (Concatenate)   (None, 32, 32, 1024) 0           activation_518[0][0]
#                                                                  activation_513[0][0]
# __________________________________________________________________________________________________
# batch_normalization_566 (BatchN (None, 32, 32, 1024) 4096        concatenate_411[0][0]
# __________________________________________________________________________________________________
# activation_519 (Activation)     (None, 32, 32, 1024) 0           batch_normalization_566[0][0]
# __________________________________________________________________________________________________
# conv2d_559 (Conv2D)             (None, 16, 16, 1024) 9438208     activation_519[0][0]
# __________________________________________________________________________________________________
# batch_normalization_567 (BatchN (None, 16, 16, 1024) 4096        conv2d_559[0][0]
# __________________________________________________________________________________________________
# activation_520 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_567[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 16, 16, 1024) 0           activation_520[0][0]
# __________________________________________________________________________________________________
# conv2d_561 (Conv2D)             (None, 16, 16, 1024) 1049600     concatenate_411[0][0]
# __________________________________________________________________________________________________
# conv2d_560 (Conv2D)             (None, 16, 16, 1024) 9438208     dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_568 (BatchN (None, 16, 16, 1024) 4096        conv2d_561[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 16, 16, 1024) 0           conv2d_560[0][0]
# __________________________________________________________________________________________________
# add_217 (Add)                   (None, 16, 16, 1024) 0           batch_normalization_568[0][0]
#                                                                  lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_562 (Conv2D)             (None, 16, 16, 1024) 1049600     add_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_569 (BatchN (None, 16, 16, 1024) 4096        conv2d_562[0][0]
# __________________________________________________________________________________________________
# activation_521 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_569[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_377 (S (None, 16, 16, 128)  0           activation_521[0][0]
# __________________________________________________________________________________________________
# conv2d_563 (Conv2D)             (None, 16, 16, 128)  147584      tf.__operators__.getitem_377[0][0
# __________________________________________________________________________________________________
# batch_normalization_570 (BatchN (None, 16, 16, 128)  512         conv2d_563[0][0]
# __________________________________________________________________________________________________
# activation_522 (Activation)     (None, 16, 16, 128)  0           batch_normalization_570[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_378 (S (None, 16, 16, 128)  0           activation_521[0][0]
# __________________________________________________________________________________________________
# add_218 (Add)                   (None, 16, 16, 128)  0           activation_522[0][0]
#                                                                  tf.__operators__.getitem_378[0][0
# __________________________________________________________________________________________________
# conv2d_564 (Conv2D)             (None, 16, 16, 128)  147584      add_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_571 (BatchN (None, 16, 16, 128)  512         conv2d_564[0][0]
# __________________________________________________________________________________________________
# activation_523 (Activation)     (None, 16, 16, 128)  0           batch_normalization_571[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_379 (S (None, 16, 16, 128)  0           activation_521[0][0]
# __________________________________________________________________________________________________
# add_219 (Add)                   (None, 16, 16, 128)  0           activation_523[0][0]
#                                                                  tf.__operators__.getitem_379[0][0
# __________________________________________________________________________________________________
# conv2d_565 (Conv2D)             (None, 16, 16, 128)  147584      add_219[0][0]
# __________________________________________________________________________________________________
# batch_normalization_572 (BatchN (None, 16, 16, 128)  512         conv2d_565[0][0]
# __________________________________________________________________________________________________
# activation_524 (Activation)     (None, 16, 16, 128)  0           batch_normalization_572[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_380 (S (None, 16, 16, 128)  0           activation_521[0][0]
# __________________________________________________________________________________________________
# add_220 (Add)                   (None, 16, 16, 128)  0           activation_524[0][0]
#                                                                  tf.__operators__.getitem_380[0][0
# __________________________________________________________________________________________________
# conv2d_566 (Conv2D)             (None, 16, 16, 128)  147584      add_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_573 (BatchN (None, 16, 16, 128)  512         conv2d_566[0][0]
# __________________________________________________________________________________________________
# activation_525 (Activation)     (None, 16, 16, 128)  0           batch_normalization_573[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_381 (S (None, 16, 16, 128)  0           activation_521[0][0]
# __________________________________________________________________________________________________
# add_221 (Add)                   (None, 16, 16, 128)  0           activation_525[0][0]
#                                                                  tf.__operators__.getitem_381[0][0
# __________________________________________________________________________________________________
# conv2d_567 (Conv2D)             (None, 16, 16, 128)  147584      add_221[0][0]
# __________________________________________________________________________________________________
# batch_normalization_574 (BatchN (None, 16, 16, 128)  512         conv2d_567[0][0]
# __________________________________________________________________________________________________
# activation_526 (Activation)     (None, 16, 16, 128)  0           batch_normalization_574[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_382 (S (None, 16, 16, 128)  0           activation_521[0][0]
# __________________________________________________________________________________________________
# add_222 (Add)                   (None, 16, 16, 128)  0           activation_526[0][0]
#                                                                  tf.__operators__.getitem_382[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_376 (S (None, 16, 16, 128)  0           activation_521[0][0]
# __________________________________________________________________________________________________
# conv2d_568 (Conv2D)             (None, 16, 16, 128)  147584      add_222[0][0]
# __________________________________________________________________________________________________
# concatenate_412 (Concatenate)   (None, 16, 16, 256)  0           tf.__operators__.getitem_376[0][0
#                                                                  activation_522[0][0]
# __________________________________________________________________________________________________
# batch_normalization_575 (BatchN (None, 16, 16, 128)  512         conv2d_568[0][0]
# __________________________________________________________________________________________________
# concatenate_413 (Concatenate)   (None, 16, 16, 384)  0           concatenate_412[0][0]
#                                                                  activation_523[0][0]
# __________________________________________________________________________________________________
# activation_527 (Activation)     (None, 16, 16, 128)  0           batch_normalization_575[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_383 (S (None, 16, 16, 128)  0           activation_521[0][0]
# __________________________________________________________________________________________________
# concatenate_414 (Concatenate)   (None, 16, 16, 512)  0           concatenate_413[0][0]
#                                                                  activation_524[0][0]
# __________________________________________________________________________________________________
# add_223 (Add)                   (None, 16, 16, 128)  0           activation_527[0][0]
#                                                                  tf.__operators__.getitem_383[0][0
# __________________________________________________________________________________________________
# concatenate_415 (Concatenate)   (None, 16, 16, 640)  0           concatenate_414[0][0]
#                                                                  activation_525[0][0]
# __________________________________________________________________________________________________
# conv2d_569 (Conv2D)             (None, 16, 16, 128)  147584      add_223[0][0]
# __________________________________________________________________________________________________
# concatenate_416 (Concatenate)   (None, 16, 16, 768)  0           concatenate_415[0][0]
#                                                                  activation_526[0][0]
# __________________________________________________________________________________________________
# batch_normalization_576 (BatchN (None, 16, 16, 128)  512         conv2d_569[0][0]
# __________________________________________________________________________________________________
# concatenate_417 (Concatenate)   (None, 16, 16, 896)  0           concatenate_416[0][0]
#                                                                  activation_527[0][0]
# __________________________________________________________________________________________________
# activation_528 (Activation)     (None, 16, 16, 128)  0           batch_normalization_576[0][0]
# __________________________________________________________________________________________________
# concatenate_418 (Concatenate)   (None, 16, 16, 1024) 0           concatenate_417[0][0]
#                                                                  activation_528[0][0]
# __________________________________________________________________________________________________
# conv2d_570 (Conv2D)             (None, 16, 16, 1024) 1049600     concatenate_418[0][0]
# __________________________________________________________________________________________________
# batch_normalization_577 (BatchN (None, 16, 16, 1024) 4096        conv2d_570[0][0]
# __________________________________________________________________________________________________
# activation_529 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_577[0][0]
# __________________________________________________________________________________________________
# concatenate_419 (Concatenate)   (None, 16, 16, 2048) 0           activation_529[0][0]
#                                                                  add_217[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_36 (Conv2DTran (None, 32, 32, 512)  4194816     concatenate_419[0][0]
# __________________________________________________________________________________________________
# batch_normalization_578 (BatchN (None, 32, 32, 512)  2048        conv2d_transpose_36[0][0]
# __________________________________________________________________________________________________
# concatenate_420 (Concatenate)   (None, 32, 32, 1536) 0           batch_normalization_578[0][0]
#                                                                  concatenate_411[0][0]
# __________________________________________________________________________________________________
# conv2d_571 (Conv2D)             (None, 32, 32, 512)  786944      concatenate_420[0][0]
# __________________________________________________________________________________________________
# batch_normalization_579 (BatchN (None, 32, 32, 512)  2048        conv2d_571[0][0]
# __________________________________________________________________________________________________
# activation_530 (Activation)     (None, 32, 32, 512)  0           batch_normalization_579[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_385 (S (None, 32, 32, 128)  0           activation_530[0][0]
# __________________________________________________________________________________________________
# conv2d_572 (Conv2D)             (None, 32, 32, 128)  147584      tf.__operators__.getitem_385[0][0
# __________________________________________________________________________________________________
# batch_normalization_580 (BatchN (None, 32, 32, 128)  512         conv2d_572[0][0]
# __________________________________________________________________________________________________
# activation_531 (Activation)     (None, 32, 32, 128)  0           batch_normalization_580[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_386 (S (None, 32, 32, 128)  0           activation_530[0][0]
# __________________________________________________________________________________________________
# add_224 (Add)                   (None, 32, 32, 128)  0           activation_531[0][0]
#                                                                  tf.__operators__.getitem_386[0][0
# __________________________________________________________________________________________________
# conv2d_573 (Conv2D)             (None, 32, 32, 128)  147584      add_224[0][0]
# __________________________________________________________________________________________________
# batch_normalization_581 (BatchN (None, 32, 32, 128)  512         conv2d_573[0][0]
# __________________________________________________________________________________________________
# activation_532 (Activation)     (None, 32, 32, 128)  0           batch_normalization_581[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_387 (S (None, 32, 32, 128)  0           activation_530[0][0]
# __________________________________________________________________________________________________
# add_225 (Add)                   (None, 32, 32, 128)  0           activation_532[0][0]
#                                                                  tf.__operators__.getitem_387[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_384 (S (None, 32, 32, 128)  0           activation_530[0][0]
# __________________________________________________________________________________________________
# conv2d_574 (Conv2D)             (None, 32, 32, 128)  147584      add_225[0][0]
# __________________________________________________________________________________________________
# concatenate_421 (Concatenate)   (None, 32, 32, 256)  0           tf.__operators__.getitem_384[0][0
#                                                                  activation_531[0][0]
# __________________________________________________________________________________________________
# batch_normalization_582 (BatchN (None, 32, 32, 128)  512         conv2d_574[0][0]
# __________________________________________________________________________________________________
# concatenate_422 (Concatenate)   (None, 32, 32, 384)  0           concatenate_421[0][0]
#                                                                  activation_532[0][0]
# __________________________________________________________________________________________________
# activation_533 (Activation)     (None, 32, 32, 128)  0           batch_normalization_582[0][0]
# __________________________________________________________________________________________________
# concatenate_423 (Concatenate)   (None, 32, 32, 512)  0           concatenate_422[0][0]
#                                                                  activation_533[0][0]
# __________________________________________________________________________________________________
# conv2d_575 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_423[0][0]
# __________________________________________________________________________________________________
# batch_normalization_583 (BatchN (None, 32, 32, 512)  2048        conv2d_575[0][0]
# __________________________________________________________________________________________________
# activation_534 (Activation)     (None, 32, 32, 512)  0           batch_normalization_583[0][0]
# __________________________________________________________________________________________________
# concatenate_424 (Concatenate)   (None, 32, 32, 2048) 0           activation_534[0][0]
#                                                                  concatenate_420[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_37 (Conv2DTran (None, 64, 64, 256)  2097408     concatenate_424[0][0]
# __________________________________________________________________________________________________
# batch_normalization_584 (BatchN (None, 64, 64, 256)  1024        conv2d_transpose_37[0][0]
# __________________________________________________________________________________________________
# concatenate_425 (Concatenate)   (None, 64, 64, 768)  0           batch_normalization_584[0][0]
#                                                                  concatenate_407[0][0]
# __________________________________________________________________________________________________
# conv2d_576 (Conv2D)             (None, 64, 64, 256)  196864      concatenate_425[0][0]
# __________________________________________________________________________________________________
# batch_normalization_585 (BatchN (None, 64, 64, 256)  1024        conv2d_576[0][0]
# __________________________________________________________________________________________________
# activation_535 (Activation)     (None, 64, 64, 256)  0           batch_normalization_585[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_389 (S (None, 64, 64, 64)   0           activation_535[0][0]
# __________________________________________________________________________________________________
# conv2d_577 (Conv2D)             (None, 64, 64, 64)   36928       tf.__operators__.getitem_389[0][0
# __________________________________________________________________________________________________
# batch_normalization_586 (BatchN (None, 64, 64, 64)   256         conv2d_577[0][0]
# __________________________________________________________________________________________________
# activation_536 (Activation)     (None, 64, 64, 64)   0           batch_normalization_586[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_390 (S (None, 64, 64, 64)   0           activation_535[0][0]
# __________________________________________________________________________________________________
# add_226 (Add)                   (None, 64, 64, 64)   0           activation_536[0][0]
#                                                                  tf.__operators__.getitem_390[0][0
# __________________________________________________________________________________________________
# conv2d_578 (Conv2D)             (None, 64, 64, 64)   36928       add_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_587 (BatchN (None, 64, 64, 64)   256         conv2d_578[0][0]
# __________________________________________________________________________________________________
# activation_537 (Activation)     (None, 64, 64, 64)   0           batch_normalization_587[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_391 (S (None, 64, 64, 64)   0           activation_535[0][0]
# ...
# __________________________________________________________________________________________________
# concatenate_435 (Concatenate)   (None, 256, 256, 192 0           batch_normalization_596[0][0]
#                                                                  concatenate_399[0][0]
# __________________________________________________________________________________________________
# conv2d_586 (Conv2D)             (None, 256, 256, 64) 12352       concatenate_435[0][0]
# __________________________________________________________________________________________________
# batch_normalization_597 (BatchN (None, 256, 256, 64) 256         conv2d_586[0][0]
# __________________________________________________________________________________________________
# activation_545 (Activation)     (None, 256, 256, 64) 0           batch_normalization_597[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_397 (S (None, 256, 256, 16) 0           activation_545[0][0]
# __________________________________________________________________________________________________
# conv2d_587 (Conv2D)             (None, 256, 256, 16) 2320        tf.__operators__.getitem_397[0][0
# __________________________________________________________________________________________________
# batch_normalization_598 (BatchN (None, 256, 256, 16) 64          conv2d_587[0][0]
# __________________________________________________________________________________________________
# activation_546 (Activation)     (None, 256, 256, 16) 0           batch_normalization_598[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_398 (S (None, 256, 256, 16) 0           activation_545[0][0]
# __________________________________________________________________________________________________
# add_230 (Add)                   (None, 256, 256, 16) 0           activation_546[0][0]
#                                                                  tf.__operators__.getitem_398[0][0
# __________________________________________________________________________________________________
# conv2d_588 (Conv2D)             (None, 256, 256, 16) 2320        add_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_599 (BatchN (None, 256, 256, 16) 64          conv2d_588[0][0]
# __________________________________________________________________________________________________
# activation_547 (Activation)     (None, 256, 256, 16) 0           batch_normalization_599[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_399 (S (None, 256, 256, 16) 0           activation_545[0][0]
# __________________________________________________________________________________________________
# add_231 (Add)                   (None, 256, 256, 16) 0           activation_547[0][0]
#                                                                  tf.__operators__.getitem_399[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_396 (S (None, 256, 256, 16) 0           activation_545[0][0]
# __________________________________________________________________________________________________
# conv2d_589 (Conv2D)             (None, 256, 256, 16) 2320        add_231[0][0]
# __________________________________________________________________________________________________
# concatenate_436 (Concatenate)   (None, 256, 256, 32) 0           tf.__operators__.getitem_396[0][0
#                                                                  activation_546[0][0]
# __________________________________________________________________________________________________
# batch_normalization_600 (BatchN (None, 256, 256, 16) 64          conv2d_589[0][0]
# __________________________________________________________________________________________________
# concatenate_437 (Concatenate)   (None, 256, 256, 48) 0           concatenate_436[0][0]
#                                                                  activation_547[0][0]
# __________________________________________________________________________________________________
# activation_548 (Activation)     (None, 256, 256, 16) 0           batch_normalization_600[0][0]
# __________________________________________________________________________________________________
# concatenate_438 (Concatenate)   (None, 256, 256, 64) 0           concatenate_437[0][0]
#                                                                  activation_548[0][0]
# __________________________________________________________________________________________________
# conv2d_590 (Conv2D)             (None, 256, 256, 64) 4160        concatenate_438[0][0]
# __________________________________________________________________________________________________
# batch_normalization_601 (BatchN (None, 256, 256, 64) 256         conv2d_590[0][0]
# __________________________________________________________________________________________________
# activation_549 (Activation)     (None, 256, 256, 64) 0           batch_normalization_601[0][0]
# __________________________________________________________________________________________________
# concatenate_439 (Concatenate)   (None, 256, 256, 256 0           activation_549[0][0]
#                                                                  concatenate_435[0][0]
# __________________________________________________________________________________________________
# conv2d_591 (Conv2D)             (None, 256, 256, 64) 147520      concatenate_439[0][0]
# __________________________________________________________________________________________________
# conv2d_592 (Conv2D)             (None, 256, 256, 2)  1154        conv2d_591[0][0]
# __________________________________________________________________________________________________
# conv2d_593 (Conv2D)             (None, 256, 256, 1)  3           conv2d_592[0][0]
# ==================================================================================================
# Total params: 33,823,653
# Trainable params: 33,797,221
# Non-trainable params: 26,432
# __________________________________________________________________________________________________
# Epoch 1/25
# (None, 256, 256, 1)
# (None, 256, 256, 1)
# (None, 256, 256, 1)
# (None, 256, 256, 1)
# 1912/1912 [==============================] - ETA: 0s - loss: 3185.1374 - ACL5: 3185.1374 - binary_crossentropy_plus_jaccard_loss: 0.3326 - dice_loss: 0.1669 - iou_coeff: 0.7218 - precision: 0.8675 - recall: 0.8114(None, 256, 256, 1)
# (None, 256, 256, 1)
# 1912/1912 [==============================] - 279s 141ms/step - loss: 3185.1628 - ACL5: 3185.1628 - binary_crossentropy_plus_jaccard_loss: 0.3326 - dice_loss: 0.1669 - iou_coeff: 0.7218 - precision: 0.8675 - recall: 0.8114 - val_loss: 2321.2688 - val_ACL5: 2321.2688 - val_binary_crossentropy_plus_jaccard_loss: 0.5628 - val_dice_loss: 0.3270 - val_iou_coeff: 0.5763 - val_precision: 0.7072 - val_recall: 0.6238
#
# Epoch 00001: val_dice_loss did not improve from 0.22185
# Epoch 2/25
# 1912/1912 [==============================] - 268s 140ms/step - loss: 3163.7864 - ACL5: 3163.7864 - binary_crossentropy_plus_jaccard_loss: 0.3356 - dice_loss: 0.1682 - iou_coeff: 0.7206 - precision: 0.8652 - recall: 0.8088 - val_loss: 2043.0193 - val_ACL5: 2043.0193 - val_binary_crossentropy_plus_jaccard_loss: 0.4929 - val_dice_loss: 0.2701 - val_iou_coeff: 0.6232 - val_precision: 0.8046 - val_recall: 0.6822
#
# Epoch 00002: val_dice_loss did not improve from 0.22185
# Epoch 3/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 3162.1203 - ACL5: 3162.1203 - binary_crossentropy_plus_jaccard_loss: 0.3388 - dice_loss: 0.1681 - iou_coeff: 0.7198 - precision: 0.8659 - recall: 0.8100 - val_loss: 2014.3413 - val_ACL5: 2014.3413 - val_binary_crossentropy_plus_jaccard_loss: 0.4936 - val_dice_loss: 0.2764 - val_iou_coeff: 0.6238 - val_precision: 0.7717 - val_recall: 0.6632
#
# Epoch 00003: val_dice_loss did not improve from 0.22185
# Epoch 4/25
# 1912/1912 [==============================] - 268s 140ms/step - loss: 3098.2023 - ACL5: 3098.2023 - binary_crossentropy_plus_jaccard_loss: 0.3322 - dice_loss: 0.1639 - iou_coeff: 0.7261 - precision: 0.8708 - recall: 0.8121 - val_loss: 2024.4038 - val_ACL5: 2024.4038 - val_binary_crossentropy_plus_jaccard_loss: 0.5348 - val_dice_loss: 0.2992 - val_iou_coeff: 0.6041 - val_precision: 0.7597 - val_recall: 0.6137
#
# Epoch 00004: val_dice_loss did not improve from 0.22185
# Epoch 5/25
# 1912/1912 [==============================] - 268s 140ms/step - loss: 3180.2609 - ACL5: 3180.2609 - binary_crossentropy_plus_jaccard_loss: 0.3432 - dice_loss: 0.1677 - iou_coeff: 0.7208 - precision: 0.8684 - recall: 0.8057 - val_loss: 1953.4122 - val_ACL5: 1953.4122 - val_binary_crossentropy_plus_jaccard_loss: 0.4833 - val_dice_loss: 0.2658 - val_iou_coeff: 0.6377 - val_precision: 0.7292 - val_recall: 0.7010
#
# Epoch 00005: val_dice_loss did not improve from 0.22185
# Epoch 6/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 3078.6434 - ACL5: 3078.6434 - binary_crossentropy_plus_jaccard_loss: 0.3315 - dice_loss: 0.1615 - iou_coeff: 0.7291 - precision: 0.8718 - recall: 0.8133 - val_loss: 2047.6166 - val_ACL5: 2047.6166 - val_binary_crossentropy_plus_jaccard_loss: 0.5137 - val_dice_loss: 0.2932 - val_iou_coeff: 0.6037 - val_precision: 0.7997 - val_recall: 0.6180
#
# Epoch 00006: val_dice_loss did not improve from 0.22185
# Epoch 7/25
# 1912/1912 [==============================] - 269s 140ms/step - loss: 3060.8382 - ACL5: 3060.8382 - binary_crossentropy_plus_jaccard_loss: 0.3286 - dice_loss: 0.1593 - iou_coeff: 0.7328 - precision: 0.8732 - recall: 0.8149 - val_loss: 1887.4274 - val_ACL5: 1887.4274 - val_binary_crossentropy_plus_jaccard_loss: 0.4483 - val_dice_loss: 0.2339 - val_iou_coeff: 0.6559 - val_precision: 0.8248 - val_recall: 0.6871
#
# Epoch 00007: val_dice_loss did not improve from 0.22185
# Epoch 8/25
# 1912/1912 [==============================] - 268s 140ms/step - loss: 3099.9583 - ACL5: 3099.9583 - binary_crossentropy_plus_jaccard_loss: 0.3366 - dice_loss: 0.1630 - iou_coeff: 0.7280 - precision: 0.8723 - recall: 0.8118 - val_loss: 2228.4878 - val_ACL5: 2228.4878 - val_binary_crossentropy_plus_jaccard_loss: 0.5802 - val_dice_loss: 0.3330 - val_iou_coeff: 0.5718 - val_precision: 0.7321 - val_recall: 0.5906
#
# Epoch 00008: val_dice_loss did not improve from 0.22185
# Epoch 9/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 3048.9457 - ACL5: 3048.9457 - binary_crossentropy_plus_jaccard_loss: 0.3298 - dice_loss: 0.1577 - iou_coeff: 0.7337 - precision: 0.8747 - recall: 0.8201 - val_loss: 1847.3389 - val_ACL5: 1847.3389 - val_binary_crossentropy_plus_jaccard_loss: 0.4363 - val_dice_loss: 0.2194 - val_iou_coeff: 0.6745 - val_precision: 0.7945 - val_recall: 0.7223
#
# Epoch 00009: val_dice_loss improved from 0.22185 to 0.21942, saving model to Res2Net.hdf5
# Epoch 10/25
# 1912/1912 [==============================] - 268s 140ms/step - loss: 2971.2440 - ACL5: 2971.2440 - binary_crossentropy_plus_jaccard_loss: 0.3227 - dice_loss: 0.1535 - iou_coeff: 0.7400 - precision: 0.8778 - recall: 0.8221 - val_loss: 1807.4253 - val_ACL5: 1807.4253 - val_binary_crossentropy_plus_jaccard_loss: 0.4525 - val_dice_loss: 0.2355 - val_iou_coeff: 0.6622 - val_precision: 0.7866 - val_recall: 0.6905
#
# Epoch 00010: val_dice_loss did not improve from 0.21942
# Epoch 11/25
# 1912/1912 [==============================] - 268s 140ms/step - loss: 2954.2206 - ACL5: 2954.2206 - binary_crossentropy_plus_jaccard_loss: 0.3290 - dice_loss: 0.1556 - iou_coeff: 0.7378 - precision: 0.8732 - recall: 0.8164 - val_loss: 1902.4081 - val_ACL5: 1902.4081 - val_binary_crossentropy_plus_jaccard_loss: 0.4362 - val_dice_loss: 0.2274 - val_iou_coeff: 0.6627 - val_precision: 0.8148 - val_recall: 0.6956
#
# Epoch 00011: val_dice_loss did not improve from 0.21942
# Epoch 12/25
# 1912/1912 [==============================] - 268s 140ms/step - loss: 2930.5595 - ACL5: 2930.5595 - binary_crossentropy_plus_jaccard_loss: 0.3221 - dice_loss: 0.1514 - iou_coeff: 0.7436 - precision: 0.8760 - recall: 0.8235 - val_loss: 1899.2891 - val_ACL5: 1899.2891 - val_binary_crossentropy_plus_jaccard_loss: 0.4511 - val_dice_loss: 0.2364 - val_iou_coeff: 0.6525 - val_precision: 0.8253 - val_recall: 0.7065
#
# Epoch 00012: val_dice_loss did not improve from 0.21942
# Epoch 13/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 2971.9861 - ACL5: 2971.9861 - binary_crossentropy_plus_jaccard_loss: 0.3293 - dice_loss: 0.1540 - iou_coeff: 0.7408 - precision: 0.8745 - recall: 0.8198 - val_loss: 1944.1794 - val_ACL5: 1944.1794 - val_binary_crossentropy_plus_jaccard_loss: 0.4611 - val_dice_loss: 0.2451 - val_iou_coeff: 0.6509 - val_precision: 0.7936 - val_recall: 0.6608
#
# Epoch 00013: val_dice_loss did not improve from 0.21942
# Epoch 14/25
# 1912/1912 [==============================] - 268s 140ms/step - loss: 2898.8328 - ACL5: 2898.8328 - binary_crossentropy_plus_jaccard_loss: 0.3223 - dice_loss: 0.1515 - iou_coeff: 0.7437 - precision: 0.8777 - recall: 0.8253 - val_loss: 1995.3682 - val_ACL5: 1995.3682 - val_binary_crossentropy_plus_jaccard_loss: 0.4720 - val_dice_loss: 0.2470 - val_iou_coeff: 0.6423 - val_precision: 0.7889 - val_recall: 0.7190
#
# Epoch 00014: val_dice_loss did not improve from 0.21942
# Epoch 15/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 2938.2653 - ACL5: 2938.2653 - binary_crossentropy_plus_jaccard_loss: 0.3253 - dice_loss: 0.1526 - iou_coeff: 0.7426 - precision: 0.8808 - recall: 0.8220 - val_loss: 1934.5515 - val_ACL5: 1934.5515 - val_binary_crossentropy_plus_jaccard_loss: 0.4711 - val_dice_loss: 0.2501 - val_iou_coeff: 0.6462 - val_precision: 0.7850 - val_recall: 0.6888
#
# Epoch 00015: val_dice_loss did not improve from 0.21942
# Epoch 16/25
# 1912/1912 [==============================] - 269s 141ms/step - loss: 2896.9222 - ACL5: 2896.9222 - binary_crossentropy_plus_jaccard_loss: 0.3209 - dice_loss: 0.1479 - iou_coeff: 0.7476 - precision: 0.8810 - recall: 0.8263 - val_loss: 1999.0140 - val_ACL5: 1999.0140 - val_binary_crossentropy_plus_jaccard_loss: 0.4788 - val_dice_loss: 0.2459 - val_iou_coeff: 0.6462 - val_precision: 0.7957 - val_recall: 0.6864
#
# Epoch 00016: val_dice_loss did not improve from 0.21942
# Epoch 17/25
# 1912/1912 [==============================] - 268s 140ms/step - loss: 2914.6907 - ACL5: 2914.6907 - binary_crossentropy_plus_jaccard_loss: 0.3243 - dice_loss: 0.1514 - iou_coeff: 0.7440 - precision: 0.8768 - recall: 0.8267 - val_loss: 1892.6913 - val_ACL5: 1892.6913 - val_binary_crossentropy_plus_jaccard_loss: 0.4596 - val_dice_loss: 0.2384 - val_iou_coeff: 0.6579 - val_precision: 0.7912 - val_recall: 0.7097
#
# Epoch 00017: val_dice_loss did not improve from 0.21942
# Epoch 18/25
# 1912/1912 [==============================] - 268s 140ms/step - loss: 2786.2385 - ACL5: 2786.2385 - binary_crossentropy_plus_jaccard_loss: 0.3094 - dice_loss: 0.1431 - iou_coeff: 0.7551 - precision: 0.8850 - recall: 0.8360 - val_loss: 2087.0630 - val_ACL5: 2087.0630 - val_binary_crossentropy_plus_jaccard_loss: 0.5479 - val_dice_loss: 0.2999 - val_iou_coeff: 0.5983 - val_precision: 0.7983 - val_recall: 0.6195
#
# Epoch 00018: val_dice_loss did not improve from 0.21942
# Epoch 19/25
# 1768/1912 [==========================>...] - ETA: 19s - loss: 2805.9215 - ACL5: 2805.9215 - binary_crossentropy_plus_jaccard_loss: 0.3131 - dice_loss: 0.1431 - iou_coeff: 0.7550 - precision: 0.8831 - recall: 0.8335

# %%
model = res2unet(lrate=8.00E-05 , pretrained_weights = './Res2Net.hdf5')


#model_checkpoint1 = keras.callbacks.ModelCheckpoint("../input/weights-res2net-conv2dtranspose/Res2Net_Conv2DTranspose.hdf5", monitor='val_dice_loss',verbose=1,mode='min',save_best_only=True)
#csv_logger = CSVLogger('trainingRes2Net.log', append=True, separator=';')
history = model.fit_generator(train_data,
                             steps_per_epoch=1912,epochs=10,
                              validation_steps=207,
                              validation_data=valid_data,
                              callbacks=[model_checkpoint1,csv_logger , learning_rate_reduction])
# Out:
# 8e-05
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_417 (Conv2D)             (None, 256, 256, 64) 1792        input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_422 (BatchN (None, 256, 256, 64) 256         conv2d_417[0][0]
# __________________________________________________________________________________________________
# activation_385 (Activation)     (None, 256, 256, 64) 0           batch_normalization_422[0][0]
# __________________________________________________________________________________________________
# conv2d_418 (Conv2D)             (None, 256, 256, 64) 4160        activation_385[0][0]
# __________________________________________________________________________________________________
# batch_normalization_423 (BatchN (None, 256, 256, 64) 256         conv2d_418[0][0]
# __________________________________________________________________________________________________
# activation_386 (Activation)     (None, 256, 256, 64) 0           batch_normalization_423[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_281 (S (None, 256, 256, 16) 0           activation_386[0][0]
# __________________________________________________________________________________________________
# conv2d_419 (Conv2D)             (None, 256, 256, 16) 2320        tf.__operators__.getitem_281[0][0
# __________________________________________________________________________________________________
# batch_normalization_424 (BatchN (None, 256, 256, 16) 64          conv2d_419[0][0]
# __________________________________________________________________________________________________
# activation_387 (Activation)     (None, 256, 256, 16) 0           batch_normalization_424[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_282 (S (None, 256, 256, 16) 0           activation_386[0][0]
# __________________________________________________________________________________________________
# add_163 (Add)                   (None, 256, 256, 16) 0           activation_387[0][0]
#                                                                  tf.__operators__.getitem_282[0][0
# __________________________________________________________________________________________________
# conv2d_420 (Conv2D)             (None, 256, 256, 16) 2320        add_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_425 (BatchN (None, 256, 256, 16) 64          conv2d_420[0][0]
# __________________________________________________________________________________________________
# activation_388 (Activation)     (None, 256, 256, 16) 0           batch_normalization_425[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_283 (S (None, 256, 256, 16) 0           activation_386[0][0]
# __________________________________________________________________________________________________
# add_164 (Add)                   (None, 256, 256, 16) 0           activation_388[0][0]
#                                                                  tf.__operators__.getitem_283[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_280 (S (None, 256, 256, 16) 0           activation_386[0][0]
# __________________________________________________________________________________________________
# conv2d_421 (Conv2D)             (None, 256, 256, 16) 2320        add_164[0][0]
# __________________________________________________________________________________________________
# concatenate_308 (Concatenate)   (None, 256, 256, 32) 0           tf.__operators__.getitem_280[0][0
#                                                                  activation_387[0][0]
# __________________________________________________________________________________________________
# batch_normalization_426 (BatchN (None, 256, 256, 16) 64          conv2d_421[0][0]
# __________________________________________________________________________________________________
# concatenate_309 (Concatenate)   (None, 256, 256, 48) 0           concatenate_308[0][0]
#                                                                  activation_388[0][0]
# __________________________________________________________________________________________________
# activation_389 (Activation)     (None, 256, 256, 16) 0           batch_normalization_426[0][0]
# __________________________________________________________________________________________________
# concatenate_310 (Concatenate)   (None, 256, 256, 64) 0           concatenate_309[0][0]
#                                                                  activation_389[0][0]
# __________________________________________________________________________________________________
# conv2d_422 (Conv2D)             (None, 256, 256, 64) 4160        concatenate_310[0][0]
# __________________________________________________________________________________________________
# batch_normalization_427 (BatchN (None, 256, 256, 64) 256         conv2d_422[0][0]
# __________________________________________________________________________________________________
# activation_390 (Activation)     (None, 256, 256, 64) 0           batch_normalization_427[0][0]
# __________________________________________________________________________________________________
# concatenate_311 (Concatenate)   (None, 256, 256, 128 0           activation_390[0][0]
#                                                                  activation_385[0][0]
# __________________________________________________________________________________________________
# conv2d_423 (Conv2D)             (None, 128, 128, 128 16512       concatenate_311[0][0]
# __________________________________________________________________________________________________
# batch_normalization_428 (BatchN (None, 128, 128, 128 512         conv2d_423[0][0]
# __________________________________________________________________________________________________
# activation_391 (Activation)     (None, 128, 128, 128 0           batch_normalization_428[0][0]
# __________________________________________________________________________________________________
# conv2d_424 (Conv2D)             (None, 128, 128, 128 16512       activation_391[0][0]
# __________________________________________________________________________________________________
# batch_normalization_429 (BatchN (None, 128, 128, 128 512         conv2d_424[0][0]
# __________________________________________________________________________________________________
# activation_392 (Activation)     (None, 128, 128, 128 0           batch_normalization_429[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_285 (S (None, 128, 128, 32) 0           activation_392[0][0]
# __________________________________________________________________________________________________
# conv2d_425 (Conv2D)             (None, 128, 128, 32) 9248        tf.__operators__.getitem_285[0][0
# __________________________________________________________________________________________________
# batch_normalization_430 (BatchN (None, 128, 128, 32) 128         conv2d_425[0][0]
# __________________________________________________________________________________________________
# activation_393 (Activation)     (None, 128, 128, 32) 0           batch_normalization_430[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_286 (S (None, 128, 128, 32) 0           activation_392[0][0]
# __________________________________________________________________________________________________
# add_165 (Add)                   (None, 128, 128, 32) 0           activation_393[0][0]
#                                                                  tf.__operators__.getitem_286[0][0
# __________________________________________________________________________________________________
# conv2d_426 (Conv2D)             (None, 128, 128, 32) 9248        add_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_431 (BatchN (None, 128, 128, 32) 128         conv2d_426[0][0]
# __________________________________________________________________________________________________
# activation_394 (Activation)     (None, 128, 128, 32) 0           batch_normalization_431[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_287 (S (None, 128, 128, 32) 0           activation_392[0][0]
# __________________________________________________________________________________________________
# add_166 (Add)                   (None, 128, 128, 32) 0           activation_394[0][0]
#                                                                  tf.__operators__.getitem_287[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_284 (S (None, 128, 128, 32) 0           activation_392[0][0]
# __________________________________________________________________________________________________
# conv2d_427 (Conv2D)             (None, 128, 128, 32) 9248        add_166[0][0]
# __________________________________________________________________________________________________
# concatenate_312 (Concatenate)   (None, 128, 128, 64) 0           tf.__operators__.getitem_284[0][0
#                                                                  activation_393[0][0]
# __________________________________________________________________________________________________
# batch_normalization_432 (BatchN (None, 128, 128, 32) 128         conv2d_427[0][0]
# __________________________________________________________________________________________________
# concatenate_313 (Concatenate)   (None, 128, 128, 96) 0           concatenate_312[0][0]
#                                                                  activation_394[0][0]
# __________________________________________________________________________________________________
# activation_395 (Activation)     (None, 128, 128, 32) 0           batch_normalization_432[0][0]
# __________________________________________________________________________________________________
# concatenate_314 (Concatenate)   (None, 128, 128, 128 0           concatenate_313[0][0]
#                                                                  activation_395[0][0]
# __________________________________________________________________________________________________
# conv2d_428 (Conv2D)             (None, 128, 128, 128 16512       concatenate_314[0][0]
# __________________________________________________________________________________________________
# batch_normalization_433 (BatchN (None, 128, 128, 128 512         conv2d_428[0][0]
# __________________________________________________________________________________________________
# activation_396 (Activation)     (None, 128, 128, 128 0           batch_normalization_433[0][0]
# __________________________________________________________________________________________________
# concatenate_315 (Concatenate)   (None, 128, 128, 256 0           activation_396[0][0]
#                                                                  activation_391[0][0]
# __________________________________________________________________________________________________
# conv2d_429 (Conv2D)             (None, 64, 64, 256)  65792       concatenate_315[0][0]
# __________________________________________________________________________________________________
# batch_normalization_434 (BatchN (None, 64, 64, 256)  1024        conv2d_429[0][0]
# __________________________________________________________________________________________________
# activation_397 (Activation)     (None, 64, 64, 256)  0           batch_normalization_434[0][0]
# __________________________________________________________________________________________________
# conv2d_430 (Conv2D)             (None, 64, 64, 256)  65792       activation_397[0][0]
# __________________________________________________________________________________________________
# batch_normalization_435 (BatchN (None, 64, 64, 256)  1024        conv2d_430[0][0]
# __________________________________________________________________________________________________
# activation_398 (Activation)     (None, 64, 64, 256)  0           batch_normalization_435[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_289 (S (None, 64, 64, 64)   0           activation_398[0][0]
# __________________________________________________________________________________________________
# conv2d_431 (Conv2D)             (None, 64, 64, 64)   36928       tf.__operators__.getitem_289[0][0
# __________________________________________________________________________________________________
# batch_normalization_436 (BatchN (None, 64, 64, 64)   256         conv2d_431[0][0]
# __________________________________________________________________________________________________
# activation_399 (Activation)     (None, 64, 64, 64)   0           batch_normalization_436[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_290 (S (None, 64, 64, 64)   0           activation_398[0][0]
# __________________________________________________________________________________________________
# add_167 (Add)                   (None, 64, 64, 64)   0           activation_399[0][0]
#                                                                  tf.__operators__.getitem_290[0][0
# __________________________________________________________________________________________________
# conv2d_432 (Conv2D)             (None, 64, 64, 64)   36928       add_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_437 (BatchN (None, 64, 64, 64)   256         conv2d_432[0][0]
# __________________________________________________________________________________________________
# activation_400 (Activation)     (None, 64, 64, 64)   0           batch_normalization_437[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_291 (S (None, 64, 64, 64)   0           activation_398[0][0]
# __________________________________________________________________________________________________
# add_168 (Add)                   (None, 64, 64, 64)   0           activation_400[0][0]
#                                                                  tf.__operators__.getitem_291[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_288 (S (None, 64, 64, 64)   0           activation_398[0][0]
# __________________________________________________________________________________________________
# conv2d_433 (Conv2D)             (None, 64, 64, 64)   36928       add_168[0][0]
# __________________________________________________________________________________________________
# concatenate_316 (Concatenate)   (None, 64, 64, 128)  0           tf.__operators__.getitem_288[0][0
#                                                                  activation_399[0][0]
# __________________________________________________________________________________________________
# batch_normalization_438 (BatchN (None, 64, 64, 64)   256         conv2d_433[0][0]
# __________________________________________________________________________________________________
# concatenate_317 (Concatenate)   (None, 64, 64, 192)  0           concatenate_316[0][0]
#                                                                  activation_400[0][0]
# __________________________________________________________________________________________________
# activation_401 (Activation)     (None, 64, 64, 64)   0           batch_normalization_438[0][0]
# __________________________________________________________________________________________________
# concatenate_318 (Concatenate)   (None, 64, 64, 256)  0           concatenate_317[0][0]
#                                                                  activation_401[0][0]
# __________________________________________________________________________________________________
# conv2d_434 (Conv2D)             (None, 64, 64, 256)  65792       concatenate_318[0][0]
# __________________________________________________________________________________________________
# batch_normalization_439 (BatchN (None, 64, 64, 256)  1024        conv2d_434[0][0]
# __________________________________________________________________________________________________
# activation_402 (Activation)     (None, 64, 64, 256)  0           batch_normalization_439[0][0]
# __________________________________________________________________________________________________
# concatenate_319 (Concatenate)   (None, 64, 64, 512)  0           activation_402[0][0]
#                                                                  activation_397[0][0]
# __________________________________________________________________________________________________
# conv2d_435 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_319[0][0]
# __________________________________________________________________________________________________
# batch_normalization_440 (BatchN (None, 32, 32, 512)  2048        conv2d_435[0][0]
# __________________________________________________________________________________________________
# activation_403 (Activation)     (None, 32, 32, 512)  0           batch_normalization_440[0][0]
# __________________________________________________________________________________________________
# conv2d_436 (Conv2D)             (None, 32, 32, 512)  262656      activation_403[0][0]
# __________________________________________________________________________________________________
# batch_normalization_441 (BatchN (None, 32, 32, 512)  2048        conv2d_436[0][0]
# __________________________________________________________________________________________________
# activation_404 (Activation)     (None, 32, 32, 512)  0           batch_normalization_441[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_293 (S (None, 32, 32, 128)  0           activation_404[0][0]
# __________________________________________________________________________________________________
# conv2d_437 (Conv2D)             (None, 32, 32, 128)  147584      tf.__operators__.getitem_293[0][0
# __________________________________________________________________________________________________
# batch_normalization_442 (BatchN (None, 32, 32, 128)  512         conv2d_437[0][0]
# __________________________________________________________________________________________________
# activation_405 (Activation)     (None, 32, 32, 128)  0           batch_normalization_442[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_294 (S (None, 32, 32, 128)  0           activation_404[0][0]
# __________________________________________________________________________________________________
# add_169 (Add)                   (None, 32, 32, 128)  0           activation_405[0][0]
#                                                                  tf.__operators__.getitem_294[0][0
# __________________________________________________________________________________________________
# conv2d_438 (Conv2D)             (None, 32, 32, 128)  147584      add_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_443 (BatchN (None, 32, 32, 128)  512         conv2d_438[0][0]
# __________________________________________________________________________________________________
# activation_406 (Activation)     (None, 32, 32, 128)  0           batch_normalization_443[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_295 (S (None, 32, 32, 128)  0           activation_404[0][0]
# __________________________________________________________________________________________________
# add_170 (Add)                   (None, 32, 32, 128)  0           activation_406[0][0]
#                                                                  tf.__operators__.getitem_295[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_292 (S (None, 32, 32, 128)  0           activation_404[0][0]
# __________________________________________________________________________________________________
# conv2d_439 (Conv2D)             (None, 32, 32, 128)  147584      add_170[0][0]
# __________________________________________________________________________________________________
# concatenate_320 (Concatenate)   (None, 32, 32, 256)  0           tf.__operators__.getitem_292[0][0
#                                                                  activation_405[0][0]
# __________________________________________________________________________________________________
# batch_normalization_444 (BatchN (None, 32, 32, 128)  512         conv2d_439[0][0]
# __________________________________________________________________________________________________
# concatenate_321 (Concatenate)   (None, 32, 32, 384)  0           concatenate_320[0][0]
#                                                                  activation_406[0][0]
# __________________________________________________________________________________________________
# activation_407 (Activation)     (None, 32, 32, 128)  0           batch_normalization_444[0][0]
# __________________________________________________________________________________________________
# concatenate_322 (Concatenate)   (None, 32, 32, 512)  0           concatenate_321[0][0]
#                                                                  activation_407[0][0]
# __________________________________________________________________________________________________
# conv2d_440 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_322[0][0]
# __________________________________________________________________________________________________
# batch_normalization_445 (BatchN (None, 32, 32, 512)  2048        conv2d_440[0][0]
# __________________________________________________________________________________________________
# activation_408 (Activation)     (None, 32, 32, 512)  0           batch_normalization_445[0][0]
# __________________________________________________________________________________________________
# concatenate_323 (Concatenate)   (None, 32, 32, 1024) 0           activation_408[0][0]
#                                                                  activation_403[0][0]
# __________________________________________________________________________________________________
# batch_normalization_446 (BatchN (None, 32, 32, 1024) 4096        concatenate_323[0][0]
# __________________________________________________________________________________________________
# activation_409 (Activation)     (None, 32, 32, 1024) 0           batch_normalization_446[0][0]
# __________________________________________________________________________________________________
# conv2d_441 (Conv2D)             (None, 16, 16, 1024) 9438208     activation_409[0][0]
# __________________________________________________________________________________________________
# batch_normalization_447 (BatchN (None, 16, 16, 1024) 4096        conv2d_441[0][0]
# __________________________________________________________________________________________________
# activation_410 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_447[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 1024) 0           activation_410[0][0]
# __________________________________________________________________________________________________
# conv2d_443 (Conv2D)             (None, 16, 16, 1024) 1049600     concatenate_323[0][0]
# __________________________________________________________________________________________________
# conv2d_442 (Conv2D)             (None, 16, 16, 1024) 9438208     dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_448 (BatchN (None, 16, 16, 1024) 4096        conv2d_443[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 16, 16, 1024) 0           conv2d_442[0][0]
# __________________________________________________________________________________________________
# add_171 (Add)                   (None, 16, 16, 1024) 0           batch_normalization_448[0][0]
#                                                                  lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_444 (Conv2D)             (None, 16, 16, 1024) 1049600     add_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_449 (BatchN (None, 16, 16, 1024) 4096        conv2d_444[0][0]
# __________________________________________________________________________________________________
# activation_411 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_449[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_297 (S (None, 16, 16, 128)  0           activation_411[0][0]
# __________________________________________________________________________________________________
# conv2d_445 (Conv2D)             (None, 16, 16, 128)  147584      tf.__operators__.getitem_297[0][0
# __________________________________________________________________________________________________
# batch_normalization_450 (BatchN (None, 16, 16, 128)  512         conv2d_445[0][0]
# __________________________________________________________________________________________________
# activation_412 (Activation)     (None, 16, 16, 128)  0           batch_normalization_450[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_298 (S (None, 16, 16, 128)  0           activation_411[0][0]
# __________________________________________________________________________________________________
# add_172 (Add)                   (None, 16, 16, 128)  0           activation_412[0][0]
#                                                                  tf.__operators__.getitem_298[0][0
# __________________________________________________________________________________________________
# conv2d_446 (Conv2D)             (None, 16, 16, 128)  147584      add_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_451 (BatchN (None, 16, 16, 128)  512         conv2d_446[0][0]
# __________________________________________________________________________________________________
# activation_413 (Activation)     (None, 16, 16, 128)  0           batch_normalization_451[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_299 (S (None, 16, 16, 128)  0           activation_411[0][0]
# __________________________________________________________________________________________________
# add_173 (Add)                   (None, 16, 16, 128)  0           activation_413[0][0]
#                                                                  tf.__operators__.getitem_299[0][0
# __________________________________________________________________________________________________
# conv2d_447 (Conv2D)             (None, 16, 16, 128)  147584      add_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_452 (BatchN (None, 16, 16, 128)  512         conv2d_447[0][0]
# __________________________________________________________________________________________________
# activation_414 (Activation)     (None, 16, 16, 128)  0           batch_normalization_452[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_300 (S (None, 16, 16, 128)  0           activation_411[0][0]
# __________________________________________________________________________________________________
# add_174 (Add)                   (None, 16, 16, 128)  0           activation_414[0][0]
#                                                                  tf.__operators__.getitem_300[0][0
# __________________________________________________________________________________________________
# conv2d_448 (Conv2D)             (None, 16, 16, 128)  147584      add_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_453 (BatchN (None, 16, 16, 128)  512         conv2d_448[0][0]
# __________________________________________________________________________________________________
# activation_415 (Activation)     (None, 16, 16, 128)  0           batch_normalization_453[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_301 (S (None, 16, 16, 128)  0           activation_411[0][0]
# __________________________________________________________________________________________________
# add_175 (Add)                   (None, 16, 16, 128)  0           activation_415[0][0]
#                                                                  tf.__operators__.getitem_301[0][0
# __________________________________________________________________________________________________
# conv2d_449 (Conv2D)             (None, 16, 16, 128)  147584      add_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_454 (BatchN (None, 16, 16, 128)  512         conv2d_449[0][0]
# __________________________________________________________________________________________________
# activation_416 (Activation)     (None, 16, 16, 128)  0           batch_normalization_454[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_302 (S (None, 16, 16, 128)  0           activation_411[0][0]
# __________________________________________________________________________________________________
# add_176 (Add)                   (None, 16, 16, 128)  0           activation_416[0][0]
#                                                                  tf.__operators__.getitem_302[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_296 (S (None, 16, 16, 128)  0           activation_411[0][0]
# __________________________________________________________________________________________________
# conv2d_450 (Conv2D)             (None, 16, 16, 128)  147584      add_176[0][0]
# __________________________________________________________________________________________________
# concatenate_324 (Concatenate)   (None, 16, 16, 256)  0           tf.__operators__.getitem_296[0][0
#                                                                  activation_412[0][0]
# __________________________________________________________________________________________________
# batch_normalization_455 (BatchN (None, 16, 16, 128)  512         conv2d_450[0][0]
# __________________________________________________________________________________________________
# concatenate_325 (Concatenate)   (None, 16, 16, 384)  0           concatenate_324[0][0]
#                                                                  activation_413[0][0]
# __________________________________________________________________________________________________
# activation_417 (Activation)     (None, 16, 16, 128)  0           batch_normalization_455[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_303 (S (None, 16, 16, 128)  0           activation_411[0][0]
# __________________________________________________________________________________________________
# concatenate_326 (Concatenate)   (None, 16, 16, 512)  0           concatenate_325[0][0]
#                                                                  activation_414[0][0]
# __________________________________________________________________________________________________
# add_177 (Add)                   (None, 16, 16, 128)  0           activation_417[0][0]
#                                                                  tf.__operators__.getitem_303[0][0
# __________________________________________________________________________________________________
# concatenate_327 (Concatenate)   (None, 16, 16, 640)  0           concatenate_326[0][0]
#                                                                  activation_415[0][0]
# __________________________________________________________________________________________________
# conv2d_451 (Conv2D)             (None, 16, 16, 128)  147584      add_177[0][0]
# __________________________________________________________________________________________________
# concatenate_328 (Concatenate)   (None, 16, 16, 768)  0           concatenate_327[0][0]
#                                                                  activation_416[0][0]
# __________________________________________________________________________________________________
# batch_normalization_456 (BatchN (None, 16, 16, 128)  512         conv2d_451[0][0]
# __________________________________________________________________________________________________
# concatenate_329 (Concatenate)   (None, 16, 16, 896)  0           concatenate_328[0][0]
#                                                                  activation_417[0][0]
# __________________________________________________________________________________________________
# activation_418 (Activation)     (None, 16, 16, 128)  0           batch_normalization_456[0][0]
# __________________________________________________________________________________________________
# concatenate_330 (Concatenate)   (None, 16, 16, 1024) 0           concatenate_329[0][0]
#                                                                  activation_418[0][0]
# __________________________________________________________________________________________________
# conv2d_452 (Conv2D)             (None, 16, 16, 1024) 1049600     concatenate_330[0][0]
# __________________________________________________________________________________________________
# batch_normalization_457 (BatchN (None, 16, 16, 1024) 4096        conv2d_452[0][0]
# __________________________________________________________________________________________________
# activation_419 (Activation)     (None, 16, 16, 1024) 0           batch_normalization_457[0][0]
# __________________________________________________________________________________________________
# concatenate_331 (Concatenate)   (None, 16, 16, 2048) 0           activation_419[0][0]
#                                                                  add_171[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_28 (Conv2DTran (None, 32, 32, 512)  4194816     concatenate_331[0][0]
# __________________________________________________________________________________________________
# batch_normalization_458 (BatchN (None, 32, 32, 512)  2048        conv2d_transpose_28[0][0]
# __________________________________________________________________________________________________
# concatenate_332 (Concatenate)   (None, 32, 32, 1536) 0           batch_normalization_458[0][0]
#                                                                  concatenate_323[0][0]
# __________________________________________________________________________________________________
# conv2d_453 (Conv2D)             (None, 32, 32, 512)  786944      concatenate_332[0][0]
# __________________________________________________________________________________________________
# batch_normalization_459 (BatchN (None, 32, 32, 512)  2048        conv2d_453[0][0]
# __________________________________________________________________________________________________
# activation_420 (Activation)     (None, 32, 32, 512)  0           batch_normalization_459[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_305 (S (None, 32, 32, 128)  0           activation_420[0][0]
# __________________________________________________________________________________________________
# conv2d_454 (Conv2D)             (None, 32, 32, 128)  147584      tf.__operators__.getitem_305[0][0
# __________________________________________________________________________________________________
# batch_normalization_460 (BatchN (None, 32, 32, 128)  512         conv2d_454[0][0]
# __________________________________________________________________________________________________
# activation_421 (Activation)     (None, 32, 32, 128)  0           batch_normalization_460[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_306 (S (None, 32, 32, 128)  0           activation_420[0][0]
# __________________________________________________________________________________________________
# add_178 (Add)                   (None, 32, 32, 128)  0           activation_421[0][0]
#                                                                  tf.__operators__.getitem_306[0][0
# __________________________________________________________________________________________________
# conv2d_455 (Conv2D)             (None, 32, 32, 128)  147584      add_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_461 (BatchN (None, 32, 32, 128)  512         conv2d_455[0][0]
# __________________________________________________________________________________________________
# activation_422 (Activation)     (None, 32, 32, 128)  0           batch_normalization_461[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_307 (S (None, 32, 32, 128)  0           activation_420[0][0]
# __________________________________________________________________________________________________
# add_179 (Add)                   (None, 32, 32, 128)  0           activation_422[0][0]
#                                                                  tf.__operators__.getitem_307[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_304 (S (None, 32, 32, 128)  0           activation_420[0][0]
# __________________________________________________________________________________________________
# conv2d_456 (Conv2D)             (None, 32, 32, 128)  147584      add_179[0][0]
# __________________________________________________________________________________________________
# concatenate_333 (Concatenate)   (None, 32, 32, 256)  0           tf.__operators__.getitem_304[0][0
#                                                                  activation_421[0][0]
# __________________________________________________________________________________________________
# batch_normalization_462 (BatchN (None, 32, 32, 128)  512         conv2d_456[0][0]
# __________________________________________________________________________________________________
# concatenate_334 (Concatenate)   (None, 32, 32, 384)  0           concatenate_333[0][0]
#                                                                  activation_422[0][0]
# __________________________________________________________________________________________________
# activation_423 (Activation)     (None, 32, 32, 128)  0           batch_normalization_462[0][0]
# __________________________________________________________________________________________________
# concatenate_335 (Concatenate)   (None, 32, 32, 512)  0           concatenate_334[0][0]
#                                                                  activation_423[0][0]
# __________________________________________________________________________________________________
# conv2d_457 (Conv2D)             (None, 32, 32, 512)  262656      concatenate_335[0][0]
# __________________________________________________________________________________________________
# batch_normalization_463 (BatchN (None, 32, 32, 512)  2048        conv2d_457[0][0]
# __________________________________________________________________________________________________
# activation_424 (Activation)     (None, 32, 32, 512)  0           batch_normalization_463[0][0]
# __________________________________________________________________________________________________
# concatenate_336 (Concatenate)   (None, 32, 32, 2048) 0           activation_424[0][0]
#                                                                  concatenate_332[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_29 (Conv2DTran (None, 64, 64, 256)  2097408     concatenate_336[0][0]
# __________________________________________________________________________________________________
# batch_normalization_464 (BatchN (None, 64, 64, 256)  1024        conv2d_transpose_29[0][0]
# __________________________________________________________________________________________________
# concatenate_337 (Concatenate)   (None, 64, 64, 768)  0           batch_normalization_464[0][0]
#                                                                  concatenate_319[0][0]
# __________________________________________________________________________________________________
# conv2d_458 (Conv2D)             (None, 64, 64, 256)  196864      concatenate_337[0][0]
# __________________________________________________________________________________________________
# batch_normalization_465 (BatchN (None, 64, 64, 256)  1024        conv2d_458[0][0]
# __________________________________________________________________________________________________
# activation_425 (Activation)     (None, 64, 64, 256)  0           batch_normalization_465[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_309 (S (None, 64, 64, 64)   0           activation_425[0][0]
# __________________________________________________________________________________________________
# conv2d_459 (Conv2D)             (None, 64, 64, 64)   36928       tf.__operators__.getitem_309[0][0
# __________________________________________________________________________________________________
# batch_normalization_466 (BatchN (None, 64, 64, 64)   256         conv2d_459[0][0]
# __________________________________________________________________________________________________
# activation_426 (Activation)     (None, 64, 64, 64)   0           batch_normalization_466[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_310 (S (None, 64, 64, 64)   0           activation_425[0][0]
# __________________________________________________________________________________________________
# add_180 (Add)                   (None, 64, 64, 64)   0           activation_426[0][0]
#                                                                  tf.__operators__.getitem_310[0][0
# __________________________________________________________________________________________________
# conv2d_460 (Conv2D)             (None, 64, 64, 64)   36928       add_180[0][0]
# __________________________________________________________________________________________________
# batch_normalization_467 (BatchN (None, 64, 64, 64)   256         conv2d_460[0][0]
# __________________________________________________________________________________________________
# activation_427 (Activation)     (None, 64, 64, 64)   0           batch_normalization_467[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_311 (S (None, 64, 64, 64)   0           activation_425[0][0]
# ...
# tf.__operators__.getitem_315 (S (None, 128, 128, 32) 0           activation_430[0][0]
# __________________________________________________________________________________________________
# add_183 (Add)                   (None, 128, 128, 32) 0           activation_432[0][0]
#                                                                  tf.__operators__.getitem_315[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_312 (S (None, 128, 128, 32) 0           activation_430[0][0]
# __________________________________________________________________________________________________
# conv2d_466 (Conv2D)             (None, 128, 128, 32) 9248        add_183[0][0]
# __________________________________________________________________________________________________
# concatenate_343 (Concatenate)   (None, 128, 128, 64) 0           tf.__operators__.getitem_312[0][0
#                                                                  activation_431[0][0]
# __________________________________________________________________________________________________
# batch_normalization_474 (BatchN (None, 128, 128, 32) 128         conv2d_466[0][0]
# __________________________________________________________________________________________________
# concatenate_344 (Concatenate)   (None, 128, 128, 96) 0           concatenate_343[0][0]
#                                                                  activation_432[0][0]
# __________________________________________________________________________________________________
# activation_433 (Activation)     (None, 128, 128, 32) 0           batch_normalization_474[0][0]
# __________________________________________________________________________________________________
# concatenate_345 (Concatenate)   (None, 128, 128, 128 0           concatenate_344[0][0]
#                                                                  activation_433[0][0]
# __________________________________________________________________________________________________
# conv2d_467 (Conv2D)             (None, 128, 128, 128 16512       concatenate_345[0][0]
# __________________________________________________________________________________________________
# batch_normalization_475 (BatchN (None, 128, 128, 128 512         conv2d_467[0][0]
# __________________________________________________________________________________________________
# activation_434 (Activation)     (None, 128, 128, 128 0           batch_normalization_475[0][0]
# __________________________________________________________________________________________________
# concatenate_346 (Concatenate)   (None, 128, 128, 512 0           activation_434[0][0]
#                                                                  concatenate_342[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_31 (Conv2DTran (None, 256, 256, 64) 131136      concatenate_346[0][0]
# __________________________________________________________________________________________________
# batch_normalization_476 (BatchN (None, 256, 256, 64) 256         conv2d_transpose_31[0][0]
# __________________________________________________________________________________________________
# concatenate_347 (Concatenate)   (None, 256, 256, 192 0           batch_normalization_476[0][0]
#                                                                  concatenate_311[0][0]
# __________________________________________________________________________________________________
# conv2d_468 (Conv2D)             (None, 256, 256, 64) 12352       concatenate_347[0][0]
# __________________________________________________________________________________________________
# batch_normalization_477 (BatchN (None, 256, 256, 64) 256         conv2d_468[0][0]
# __________________________________________________________________________________________________
# activation_435 (Activation)     (None, 256, 256, 64) 0           batch_normalization_477[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_317 (S (None, 256, 256, 16) 0           activation_435[0][0]
# __________________________________________________________________________________________________
# conv2d_469 (Conv2D)             (None, 256, 256, 16) 2320        tf.__operators__.getitem_317[0][0
# __________________________________________________________________________________________________
# batch_normalization_478 (BatchN (None, 256, 256, 16) 64          conv2d_469[0][0]
# __________________________________________________________________________________________________
# activation_436 (Activation)     (None, 256, 256, 16) 0           batch_normalization_478[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_318 (S (None, 256, 256, 16) 0           activation_435[0][0]
# __________________________________________________________________________________________________
# add_184 (Add)                   (None, 256, 256, 16) 0           activation_436[0][0]
#                                                                  tf.__operators__.getitem_318[0][0
# __________________________________________________________________________________________________
# conv2d_470 (Conv2D)             (None, 256, 256, 16) 2320        add_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_479 (BatchN (None, 256, 256, 16) 64          conv2d_470[0][0]
# __________________________________________________________________________________________________
# activation_437 (Activation)     (None, 256, 256, 16) 0           batch_normalization_479[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_319 (S (None, 256, 256, 16) 0           activation_435[0][0]
# __________________________________________________________________________________________________
# add_185 (Add)                   (None, 256, 256, 16) 0           activation_437[0][0]
#                                                                  tf.__operators__.getitem_319[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_316 (S (None, 256, 256, 16) 0           activation_435[0][0]
# __________________________________________________________________________________________________
# conv2d_471 (Conv2D)             (None, 256, 256, 16) 2320        add_185[0][0]
# __________________________________________________________________________________________________
# concatenate_348 (Concatenate)   (None, 256, 256, 32) 0           tf.__operators__.getitem_316[0][0
#                                                                  activation_436[0][0]
# __________________________________________________________________________________________________
# batch_normalization_480 (BatchN (None, 256, 256, 16) 64          conv2d_471[0][0]
# __________________________________________________________________________________________________
# concatenate_349 (Concatenate)   (None, 256, 256, 48) 0           concatenate_348[0][0]
#                                                                  activation_437[0][0]
# __________________________________________________________________________________________________
# activation_438 (Activation)     (None, 256, 256, 16) 0           batch_normalization_480[0][0]
# __________________________________________________________________________________________________
# concatenate_350 (Concatenate)   (None, 256, 256, 64) 0           concatenate_349[0][0]
#                                                                  activation_438[0][0]
# __________________________________________________________________________________________________
# conv2d_472 (Conv2D)             (None, 256, 256, 64) 4160        concatenate_350[0][0]
# __________________________________________________________________________________________________
# batch_normalization_481 (BatchN (None, 256, 256, 64) 256         conv2d_472[0][0]
# __________________________________________________________________________________________________
# activation_439 (Activation)     (None, 256, 256, 64) 0           batch_normalization_481[0][0]
# __________________________________________________________________________________________________
# concatenate_351 (Concatenate)   (None, 256, 256, 256 0           activation_439[0][0]
#                                                                  concatenate_347[0][0]
# __________________________________________________________________________________________________
# conv2d_473 (Conv2D)             (None, 256, 256, 64) 147520      concatenate_351[0][0]
# __________________________________________________________________________________________________
# conv2d_474 (Conv2D)             (None, 256, 256, 2)  1154        conv2d_473[0][0]
# __________________________________________________________________________________________________
# conv2d_475 (Conv2D)             (None, 256, 256, 1)  3           conv2d_474[0][0]
# ==================================================================================================
# Total params: 33,823,653
# Trainable params: 33,797,221
# Non-trainable params: 26,432
# __________________________________________________________________________________________________
# Epoch 1/10
# (None, 256, 256, 1)
# (None, 256, 256, 1)
#  633/1912 [========>.....................] - ETA: 2:56 - loss: 0.3077 - ACL5: 3462.7087 - binary_crossentropy_plus_jaccard_loss: 0.3077 - dice_loss: 0.1719 - iou_coeff: 0.7149 - precision: 0.8321 - recall: 0.8408
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-5937029fa07c> in <module>
#       8                               validation_steps=207,
#       9                               validation_data=valid_data,
# ---> 10                               callbacks=[model_checkpoint1,csv_logger , learning_rate_reduction])
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1859         use_multiprocessing=use_multiprocessing,
#    1860         shuffle=shuffle,
# -> 1861         initial_epoch=initial_epoch)
#    1862
#    1863   def evaluate_generator(self,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1103               logs = tmp_logs  # No error, now safe to assign to logs.
#    1104               end_step = step + data_handler.step_increment
# -> 1105               callbacks.on_train_batch_end(end_step, logs)
#    1106               if self.stop_training:
#    1107                 break
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     452     """
#     453     if self._should_call_train_batch_hooks:
# --> 454       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     455
#     456   def on_test_batch_begin(self, batch, logs=None):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     294       self._call_batch_begin_hook(mode, batch, logs)
#     295     elif hook == 'end':
# --> 296       self._call_batch_end_hook(mode, batch, logs)
#     297     else:
#     298       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354       hook = getattr(callback, hook_name)
#     355       if getattr(callback, '_supports_tf_logs', False):
# --> 356         hook(batch, logs)
#     357       else:
#     358         if numpy_logs is None:  # Only convert once.
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1018
#    1019   def on_train_batch_end(self, batch, logs=None):
# -> 1020     self._batch_update_progbar(batch, logs)
#    1021
#    1022   def on_test_batch_end(self, batch, logs=None):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1082     if self.verbose == 1:
#    1083       # Only block async when verbose = 1.
# -> 1084       logs = tf_utils.to_numpy_or_python_type(logs)
#    1085       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1086
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     512     return t  # Don't turn ragged or sparse tensors to NumPy.
#     513
# --> 514   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     515
#     516
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     508   def _to_single_numpy_or_python_type(t):
#     509     if isinstance(t, ops.Tensor):
# --> 510       x = t.numpy()
#     511       return x.item() if np.ndim(x) == 0 else x
#     512     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1069     """
#    1070     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1071     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1072     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1073
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1035   def _numpy(self):
#    1036     try:
# -> 1037       return self._numpy_internal()
#    1038     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1039       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
history = model.fit_generator(train_data,
                             steps_per_epoch=1912,epochs=10,
                              validation_steps=207,
                              validation_data=valid_data,
                              callbacks=[model_checkpoint1,csv_logger])

# %%
#path to images
train_path = "../input/training/training"
image_folder = "images"
label_folder = "label"
valid_path =  "../input/validation/Validation"
valid_image_folder ="images"
valid_label_folder = "label"
log_filepath = './log'
flag_multi_class = False
num_classes = 2
test_path = "../input/testdata/Test/images"
save_path = "./"
dp = data_preprocess(train_path=train_path,image_folder=image_folder,label_folder=label_folder,
                     valid_path=valid_path,valid_image_folder=valid_image_folder,valid_label_folder=valid_label_folder,
                     flag_multi_class=flag_multi_class,
                     num_classes=num_classes , test_path = test_path , save_path = save_path)

train_data = dp.trainGenerator(batch_size=2)
valid_data = dp.validLoad(batch_size=1)
test_data = dp.testGenerator()

# %%
ypred = model.predict(test_data)

# %%
plt.imshow(ypred[1])

# %%
plt.imshow(ypred[0])

# %%
test_path = '../input/testdata/Test'
test_image_folder ="images"
Test_path = test_path + '/' + 'test_image_folder'
test_label_folder ="label"


import os
  
# Directory
directory = "RESULT_Res2Net_Conv2DTransposeLayers1"
  
# Parent Directory path
parent_dir = "./"
  
# Path
path = os.path.join(parent_dir, directory)
os.mkdir(path)

# %%
plt.imshow(ypred[0])

# %%
if __name__ == "__main__":
    ## Dataset
    
    #batch_size = 8
    #(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data("/content/drive/MyDrive/Test")
    test_x = os.listdir(os.path.join(test_path ,test_image_folder ))
    test_y = os.listdir(os.path.join(test_path ,test_label_folder ))
    
    TEST_X = []
    TEST_Y = []
    for img_file_name in test_x:
        TEST_X.append('../input/testdata/Test/images' + "/" +img_file_name)
        
    for label_file_name in test_y:
        TEST_Y.append('../input/testdata/Test/label'+ "/" +label_file_name)
    #test_dataset = tf_dataset( TEST_X , TEST_Y, batch=batch_size)

    #test_steps = (len(TEST_X)//batch_size)
    #if len(TEST_X) % batch_size != 0:
    #    test_steps += 1

    #with CustomObjectScope({'iou': iou}):
    #    model = tf.keras.models.load_model("/content/drive/model.h5")

    #model.evaluate(test_dataset, steps=test_steps)

    for i, (x, y) in tqdm(enumerate(zip(TEST_X, TEST_Y)), total=len(TEST_X)):
        x = io.imread(x , as_gray = True)
        x = trans.resize(x, (256, 256), mode='constant')
        #x = x[: , : , :3]
        y = io.imread(y , as_gray = True )
        y = trans.resize(y, (256 , 256), mode='constant')
        
        #y = y[: , : , :3]
        #print(x.shape)
        #print(y.shape)
        #print(x.shape)
        #print(ypred[i].reshape)
        pred_img = np.reshape(ypred[i], (256 , 256))
        #y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
        h, w = x.shape
        #plt.imshow(pred_img* 255.0)
        #break
        white_line = np.ones((h, 10)) * 255.0

        all_images = [
            x * 255.0, white_line,
            y * 255.0, white_line,
            pred_img * 255.0
        ]
        image = np.concatenate(all_images, axis=1)
        
        cv2.imwrite(f"./RESULT_Res2Net_Conv2DTransposeLayers1/{i}.png", image)

# %%
import shutil
from shutil import make_archive
shutil.make_archive("./RESULT_Res2Net_Conv2DTransposeLayers1", 'zip', "./RESULT_Res2Net_Conv2DTransposeLayers1")
